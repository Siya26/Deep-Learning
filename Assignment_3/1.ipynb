# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np

# %% [markdown]
# Preprocessing and loading data

# %%
def embedd(data):
    x = []
    y = []

    for _, row in data.iterrows():
        x_word = row['Sentence']
        y_word = row['Transformed sentence']

        x_letters = list(x_word)
        y_letters = list(y_word)

        x_numericalized_word = [ord(letter) - ord('a') + 1 for letter in x_letters]
        y_numericalized_word = [0] + [ord(letter) - ord('a') + 1 for letter in y_letters]

        x.append(x_numericalized_word)
        y.append(y_numericalized_word)

    return x, y

train_data = pd.read_csv('train_data.csv')
x_train, y_train = embedd(train_data)

x_train = np.array(x_train)
y_train = np.array(y_train)

y_train_dup = np.copy(y_train)
y_train_dup = np.delete(y_train_dup, 0, 1)
y_train = np.delete(y_train, -1, 1)

x_train = torch.LongTensor(x_train)
y_train = torch.LongTensor(y_train)
y_train_dup = torch.LongTensor(y_train_dup)

# %% [markdown]
# Positional Encoding Class

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len):
        super(PositionalEncoding, self).__init__()
        self.positional_encoding = self.get_positional_encoding(d_model, max_len)
        self.dropout = nn.Dropout(0.1)

    def get_positional_encoding(self, d_model, max_len):
        position = torch.arange(0, max_len).view(-1, 1)
        div_term = torch.exp(torch.arange(0, d_model, 2) * -(np.log(10000.0) / d_model))
        pe = torch.zeros(max_len, d_model)
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        return pe

    def forward(self, x):
        x = x + self.positional_encoding[:x.size(0), :]
        return self.dropout(x)

# %% [markdown]
# Transformer Class

# %%
class TransformerWithPositionalEncoding(nn.Module):
    def __init__(self, n_tokens, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, max_len, dropout=0.2):
        super(TransformerWithPositionalEncoding, self).__init__()
        self.embedding = nn.Embedding(n_tokens, d_model)
        self.pos_encoder = PositionalEncoding(d_model, max_len)
        self.transformer = nn.Transformer(d_model, nhead, num_encoder_layers, num_decoder_layers, dropout=dropout, batch_first=True,activation='relu', dim_feedforward=300)
        self.fc = nn.Linear(d_model, n_tokens)

    def forward(self, src, tgt):
        src = self.embedding(src)
        src = self.pos_encoder(src)
        tgt = self.embedding(tgt)
        tgt = self.pos_encoder(tgt)
        output = self.transformer(src, tgt)
        output = self.fc(output)
        return output

# %% [markdown]
# Train function

# %%
def train(model, loader, optimizer, criterion, num_epochs, batch_size):
    model.train()

    for epoch in range(num_epochs):
        total_loss = 0
        for x_batch, y_batch, y_dup_batch in loader:

            optimizer.zero_grad()
            output = model(x_batch, y_batch)
            loss = criterion(output.view(-1, 27), y_dup_batch.view(-1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print('Epoch: {}, Loss: {}'.format(epoch, total_loss / len(loader)))

# %% [markdown]
# Training the model

# %%
n_tokens = 27  
d_model = 300
dropout = 0.2
num_epochs = 100
batch_size = 32
nhead = 2
num_encoder_layers = 2
num_decoder_layers = 2
max_len = x_train.shape[0]
dim_feedforward = 300

train_dataset = torch.utils.data.TensorDataset(x_train, y_train, y_train_dup)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

model = TransformerWithPositionalEncoding(n_tokens, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, max_len, dropout)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

train(model, train_loader, optimizer, criterion, num_epochs, batch_size)
# Out:
# Epoch: 0, Loss: 2.9905494010611755
# Epoch: 1, Loss: 2.50844508218983
# Epoch: 2, Loss: 2.408306003161217
# Epoch: 3, Loss: 2.3678059654148744
# Epoch: 4, Loss: 2.336822781932953
# Epoch: 5, Loss: 2.3244878004675043
# Epoch: 6, Loss: 2.309739756257567
# Epoch: 7, Loss: 2.300274648622835
# Epoch: 8, Loss: 2.2858866186446796
# Epoch: 9, Loss: 2.2816131964121777
# Epoch: 10, Loss: 2.271703597073141
# Epoch: 11, Loss: 2.264275477901441
# Epoch: 12, Loss: 2.256296829545879
# Epoch: 13, Loss: 2.254573964637164
# Epoch: 14, Loss: 2.243974271974607
# Epoch: 15, Loss: 2.2387758596847047
# Epoch: 16, Loss: 2.230601513222472
# Epoch: 17, Loss: 2.222371438866881
# Epoch: 18, Loss: 2.214102838681713
# Epoch: 19, Loss: 2.2077877989642696
# Epoch: 20, Loss: 2.196656235821171
# Epoch: 21, Loss: 2.193313281830043
# Epoch: 22, Loss: 2.1835959327819685
# Epoch: 23, Loss: 2.179123483292044
# Epoch: 24, Loss: 2.1674943645250853
# Epoch: 25, Loss: 2.163578525525794
# Epoch: 26, Loss: 2.155235687891642
# Epoch: 27, Loss: 2.150220865528333
# Epoch: 28, Loss: 2.1411956140439803
# Epoch: 29, Loss: 2.137569731228972
# Epoch: 30, Loss: 2.1300772237995442
# Epoch: 31, Loss: 2.130190189026262
# Epoch: 32, Loss: 2.1209749620254725
# Epoch: 33, Loss: 2.115277190186662
# Epoch: 34, Loss: 2.112041710718582
# Epoch: 35, Loss: 2.107859925047992
# Epoch: 36, Loss: 2.1007498736795225
# Epoch: 37, Loss: 2.0995305183271293
# Epoch: 38, Loss: 2.0908559402918705
# Epoch: 39, Loss: 2.092107999270365
# Epoch: 40, Loss: 2.0880390705038967
# Epoch: 41, Loss: 2.083793339663989
# Epoch: 42, Loss: 2.0795039940098103
# Epoch: 43, Loss: 2.0757409731547036
# Epoch: 44, Loss: 2.0697356576788914
# Epoch: 45, Loss: 2.0666478289861114
# Epoch: 46, Loss: 2.0646461123200854
# Epoch: 47, Loss: 2.059495403342051
# Epoch: 48, Loss: 2.058165023315987
# Epoch: 49, Loss: 2.054092690824918
# Epoch: 50, Loss: 2.048014658771149
# Epoch: 51, Loss: 2.0466527089680713
# Epoch: 52, Loss: 2.043301251380955
# Epoch: 53, Loss: 2.039359232062074
# Epoch: 54, Loss: 2.038036976775078
# Epoch: 55, Loss: 2.03330030234437
# Epoch: 56, Loss: 2.026873447035001
# Epoch: 57, Loss: 2.024305684925759
# Epoch: 58, Loss: 2.022248161437849
# Epoch: 59, Loss: 2.0186145496150676
# Epoch: 60, Loss: 2.0165683025638805
# Epoch: 61, Loss: 2.013705751667284
# Epoch: 62, Loss: 2.0123282273610434
# Epoch: 63, Loss: 2.008339384919432
# Epoch: 64, Loss: 2.0079971829505814
# Epoch: 65, Loss: 2.004775900818986
# Epoch: 66, Loss: 1.9970259677329565
# Epoch: 67, Loss: 1.994570724496014
# Epoch: 68, Loss: 1.9934025235372046
# Epoch: 69, Loss: 1.989393130829345
# Epoch: 70, Loss: 1.9924832451833439
# Epoch: 71, Loss: 1.981936900583032
# Epoch: 72, Loss: 1.980644337662823
# Epoch: 73, Loss: 1.980600827905141
# Epoch: 74, Loss: 1.9800508871470412
# Epoch: 75, Loss: 1.9713922619275306
# Epoch: 76, Loss: 1.9708332786821339
# Epoch: 77, Loss: 1.9665078305762653
# Epoch: 78, Loss: 1.9690576525039325
# Epoch: 79, Loss: 1.9672931410950614
# Epoch: 80, Loss: 1.9640903070092746
# Epoch: 81, Loss: 1.9612379133973492
# Epoch: 82, Loss: 1.9581206830124878
# Epoch: 83, Loss: 1.95475485063579
# Epoch: 84, Loss: 1.9531317350526922
# Epoch: 85, Loss: 1.9465135330478895
# Epoch: 86, Loss: 1.9407765048823944
# Epoch: 87, Loss: 1.9407979266284263
# Epoch: 88, Loss: 1.9386778596329362
# Epoch: 89, Loss: 1.940352403409949
# Epoch: 90, Loss: 1.9309880967553892
# Epoch: 91, Loss: 1.9368367211459434
# Epoch: 92, Loss: 1.9318434794743855
# Epoch: 93, Loss: 1.9262987669200113
# Epoch: 94, Loss: 1.922247357020095
# Epoch: 95, Loss: 1.9275603974790878
# Epoch: 96, Loss: 1.9229676206362303
# Epoch: 97, Loss: 1.9176891421618527
# Epoch: 98, Loss: 1.9117816403576229
# Epoch: 99, Loss: 1.9108141459286485

# %% [markdown]
# Saving and loading the model

# %%
torch.save(model.state_dict(), 'model_final.pt')
model.load_state_dict(torch.load('model_final.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Predict function

# %%
def predict(model, string):
    model.eval()
    x_letters = list(string)
    x_numericalized_word = [ord(letter) - ord('a') + 1 for letter in x_letters]
    x_numericalized_word = torch.LongTensor(x_numericalized_word)
    x_numericalized_word = x_numericalized_word.unsqueeze(0)
    y_numericalized_word = [0] 
    y_numericalized_word = torch.LongTensor(y_numericalized_word)
    y_numericalized_word = y_numericalized_word.unsqueeze(0)

    for i in range(8):
        #print(x_numericalized_word.shape, y_numericalized_word.shape)
        output = model(x_numericalized_word, y_numericalized_word)
        output = output.argmax(dim=2)
        y_numericalized_word = torch.cat((y_numericalized_word, output[:, -1].unsqueeze(0)), dim=1)

    y_numericalized_word = y_numericalized_word.squeeze(0)
    y_numericalized_word = y_numericalized_word.tolist()
    y_numericalized_word = [chr(letter + ord('a') - 1) for letter in y_numericalized_word]
    y_word = ''.join(y_numericalized_word)
    return y_word

# %% [markdown]
# Checker script

# %%
def predict(model, input_str):
    model.eval()
    input_str = [ord(c) - 96 for c in input_str]
    input_str = np.array([np.array(input_str)])
    input_str = torch.from_numpy(input_str)
    output = model(input_str, input_str)
    output = output.detach().numpy()
    output = output.argmax(axis=2)
    output = output[0]
    output = [chr(c + 96) for c in output]
    output = "".join(output)
    return output

# Function to check how many characters match in the two strings
def check(pred: str, true: str):
    correct = 0
    for a, b in zip(pred, true):
        if a == b:
            correct += 1
    return correct

# Function to score the model's performance
def evaluate(model):
    print("Obtaining metrics for eval data:")
    eval_data = pd.read_csv("eval_data.csv").to_numpy()
    results = {
        "pred": [],
        "true": [],
        "score": [],
    }
    correct = [0 for _ in range(9)]
    for x, y in eval_data:
        pred = predict(model, x)
        print(f"Predicted: {pred}, True: {y}")
        score = check(pred, y)
        results["pred"].append(pred)
        results["true"].append(y)
        results["score"].append(score)

        correct[score] += 1
    print("Eval dataset results:")
    for num_chr in range(9):
        print(
            f"Number of predictions with {num_chr} correct predictions: {correct[num_chr]}"
        )
    points = sum(correct[4:6]) * 0.5 + sum(correct[6:])
    marks = round(min(2, points / 1400 * 2) * 2) / 2  # Rounds to the nearest 0.5
    print(f"Points: {points}")
    print(f"Marks: {marks}")
    # Save predicitons and true sentences to inspect manually if required.
    pd.DataFrame.from_dict(results).to_csv("results_eval.csv", index=False)


evaluate(model)
# Out:
# Obtaining metrics for eval data:
# Predicted: xaaxaaax, True: ldlhgjuj
# Predicted: yyyayyay, True: mffolhhl
# Predicted: qnqnnnnn, True: xjwbqnnq
# Predicted: eoxfpebe, True: nqxwxmtb
# Predicted: nknknxxp, True: dlbdbgvx
# Predicted: ggngpgpg, True: fwkibsou
# Predicted: gbggbbbg, True: ulafntih
# Predicted: rssrssrs, True: ontitdlb
# Predicted: ovfoooof, True: epprjfot
# Predicted: daddqdad, True: sdgztwup
# Predicted: uuuguguq, True: sqcdadyx
# Predicted: fqouuoqq, True: ojsllopa
# Predicted: araaanna, True: zdtsndhk
# Predicted: zqvzyzfq, True: kiwtuwyj
# Predicted: fffffbfb, True: jxfwiaky
# Predicted: aaqivinr, True: cxqzjrox
# Predicted: tttrefte, True: vyakrkdv
# Predicted: vtttzzvd, True: rfoaeevr
# Predicted: bbbdgaga, True: bgbcvwei
# Predicted: rrrarrra, True: yrozhdru
# Predicted: irooxiii, True: gnulhwmv
# Predicted: ribigibg, True: kflttcgt
# Predicted: xxzzxxwr, True: tlcmfsqf
# Predicted: gvmmbvee, True: kwnizswj
# Predicted: nwnwwwnn, True: ebyojfqs
# Predicted: sstsnsbb, True: eyfqqwxb
# Predicted: huuuhuhu, True: prgzmfap
# Predicted: gxxqofxg, True: urmvnzmp
# Predicted: dkweddkk, True: itpsafkp
# Predicted: jnaajnqp, True: gpksonaz
# Predicted: rprkkkkr, True: xyhzjnnc
# Predicted: xofwjufx, True: toqhxqfm
# Predicted: vepiivpe, True: qepqztyt
# Predicted: ggtttitt, True: yjnifefh
# Predicted: xphrrzop, True: usjbjkge
# Predicted: nnnleebt, True: njdgirlv
# Predicted: iqmqiwjq, True: roapftdm
# Predicted: akdoykko, True: mbceqtud
# Predicted: ttttddtt, True: xewtalxz
# Predicted: vkkkkkkk, True: pifykzti
# Predicted: vkkkkvze, True: pjnobapi
# Predicted: ffftftmf, True: xyabkdzb
# Predicted: pebfeffp, True: bzksupiw
# Predicted: nkydnayk, True: bfsjlqks
# Predicted: hhwohhhw, True: fthjqsqz
# Predicted: trrtrrrr, True: mkelgcfa
# Predicted: vgvtrgvg, True: xgljdrqh
# Predicted: euueeeue, True: ulqiamgx
# Predicted: nnxnnxxn, True: tbotnnnx
# Predicted: liblblll, True: ayxthnwg
# Predicted: rrrrbjjg, True: ocutpuma
# Predicted: ennnsfns, True: ruiunvnv
# Predicted: ubbubbuu, True: nvmyhofq
# Predicted: nuxxxxnn, True: dmihohme
# Predicted: tzntbczn, True: jnnhbhwu
# Predicted: tbbbtbbb, True: jgnkvigc
# Predicted: sjsmssss, True: vthmsydf
# Predicted: hixxxxdb, True: agoighyc
# Predicted: xxyjxjxm, True: urodyanz
# Predicted: fuufuffu, True: ewjnedwf
# Predicted: ekvrrvkv, True: ufkhapao
# Predicted: ggfgggfo, True: pohxluuh
# Predicted: mdnmmnym, True: mzfmihwb
# Predicted: vvvvvvrr, True: grtqxpkg
# Predicted: pcggcgcc, True: ihqzfuyh
# Predicted: eibabaiu, True: mtrijxpx
# Predicted: ziiiiizi, True: jacunzrt
# Predicted: nujnjkss, True: jmsibxzx
# Predicted: vvbbegvv, True: zxmouros
# Predicted: vccpvppj, True: qcylwjij
# Predicted: lgsqflqa, True: jcjguuml
# Predicted: tpprwrrr, True: htoylrdy
# Predicted: bbffbfbp, True: hdbsyxgo
# Predicted: ffffffzf, True: twhrzhpo
# Predicted: zzhzzzzh, True: tzozbzkq
# Predicted: ahhhihhi, True: xektrpxg
# Predicted: ptijiewu, True: uylvafqt
# Predicted: yjhyyjyy, True: ielmvefm
# Predicted: jlqnqlss, True: eshozycp
# Predicted: wwwjuwwu, True: rwsrjndq
# Predicted: yyuuyyuu, True: bqfvtvxy
# Predicted: zzzzxeez, True: pdjbtfke
# Predicted: jzqgqqzz, True: fcecxdvp
# Predicted: czzzcczz, True: zdykapht
# Predicted: sasbasaa, True: bvziihmm
# Predicted: tfstqqss, True: ytdykoen
# Predicted: eeeiiiei, True: athycupc
# Predicted: qnlnnlll, True: iptnopxl
# Predicted: kafyckky, True: jptifnpk
# Predicted: ssssssss, True: vdhsxrwj
# Predicted: illyiyii, True: seefipbg
# Predicted: lmjymlel, True: vjlwvipa
# Predicted: iaawiiii, True: cjukedpm
# Predicted: yanaxcga, True: ibkkidaj
# Predicted: khhhhhkh, True: jgmslnfn
# Predicted: ixuxirri, True: hjsfgtef
# Predicted: xxxpxxxx, True: tndaarzp
# Predicted: cczccczc, True: jsooxfnj
# Predicted: vvddcumv, True: regsxhwc
# Predicted: yrrkiisy, True: chbwfbec
# Predicted: uobbbuou, True: ivlrotew
# Predicted: auxulala, True: zmjofhrn
# Predicted: mefafufm, True: ahhbkcph
# Predicted: ggmofgif, True: kmgsiuey
# Predicted: yeeeyeee, True: zoyzpdal
# Predicted: ppxpptxt, True: fvejjgmq
# Predicted: hqtutttq, True: lzarfold
# Predicted: vwwppppp, True: dfyppwom
# Predicted: tstsstst, True: lqfnfude
# Predicted: izizizzz, True: sohvxbag
# Predicted: vrvdzrvv, True: cmpldiln
# Predicted: ofeosslo, True: bczttemb
# Predicted: exddnaee, True: hxtrzjmk
# Predicted: kklkdklk, True: srnldykf
# Predicted: jppoppjp, True: exjxkykw
# Predicted: gggguhhu, True: negfdyxu
# Predicted: ssuhsssc, True: ojlooxle
# Predicted: upujmkju, True: aydfgvcj
# Predicted: doumlndm, True: gctmyezn
# Predicted: aaazazaz, True: ffbbwble
# Predicted: yytftppn, True: qtvtmkbh
# Predicted: yyyyqysq, True: vgnkumyd
# Predicted: kkulkhed, True: vplwtikn
# Predicted: bubuuuuu, True: banzppfc
# Predicted: gmgpgggp, True: mfviehch
# Predicted: xffffffx, True: gitizcxg
# Predicted: fyvpwfpm, True: ddywdmal
# Predicted: mqvpqqvv, True: xggnwnus
# Predicted: vvcyyycl, True: qcroadog
# Predicted: ovorarga, True: llxpluuk
# Predicted: xdotjukk, True: oqonzwpz
# Predicted: zzzzziii, True: pmecrdoe
# Predicted: smsmsssi, True: jgxjqgmg
# Predicted: yyuuffyf, True: jojlvweb
# Predicted: aiigaiii, True: penwupbo
# Predicted: yloccpec, True: iymlgbkl
# Predicted: uukuuuuk, True: cnfsqbfk
# Predicted: dkrkrlke, True: bwfxajdv
# Predicted: uccuccuc, True: aoxbcnhw
# Predicted: sssanrrr, True: mjepyffl
# Predicted: nnnnnxxi, True: pembeknx
# Predicted: mtmtmmot, True: mehxshat
# Predicted: ixiwiwaa, True: zuqctwsm
# Predicted: yafaffaf, True: pmbnxsub
# Predicted: omokoook, True: vgmphiaz
# Predicted: nmlmlnlm, True: mlsxgxzf
# Predicted: pepppssp, True: toovedaw
# Predicted: kkkynkky, True: ikececqc
# Predicted: zzyzyzzz, True: zrsbrlfv
# Predicted: thyhwttb, True: oyayqhoy
# Predicted: daujjppd, True: sstpmimx
# Predicted: hhhmhmhm, True: xiegnnzr
# Predicted: grjkafaj, True: ynyhgmhh
# Predicted: qcspscpw, True: roppiugi
# Predicted: umbmzbgz, True: bqnooszc
# Predicted: pdbpddbd, True: qikonpop
# Predicted: stkbbtbb, True: oucblwms
# Predicted: ddssdudi, True: pvldrmgo
# Predicted: ovvgvovv, True: qhhpwvlh
# Predicted: sbssttbs, True: jlnnlmbb
# Predicted: trttrbrv, True: pfarkofu
# Predicted: qqqqeeee, True: udgahosk
# Predicted: ppjpwpjj, True: vjfbzgpz
# Predicted: qyseeiqq, True: wkgajrdg
# Predicted: mmmmxmmx, True: ocbvmkmf
# Predicted: frvrroir, True: cuclqvcp
# Predicted: hasswbhw, True: nyiyuupm
# Predicted: kskkskkk, True: glimsaal
# Predicted: zmzdmzzz, True: knmewove
# Predicted: kmkxxcxv, True: txvwptte
# Predicted: aryycxay, True: tqirvati
# Predicted: mjfrjfmj, True: wmjwcpzh
# Predicted: ddzdzzzz, True: kwrpoqcj
# Predicted: fuzivusb, True: tfosqgpn
# Predicted: zvvzzzzz, True: kqptzoll
# Predicted: hhcrhhhc, True: nxduzfje
# Predicted: cxduucuu, True: nnqpbdvp
# Predicted: zzzhhhhh, True: ewwxabar
# Predicted: xtaiatta, True: clerycsk
# Predicted: bbjjjtjj, True: ekbvolny
# Predicted: hkhcrckz, True: uhoodxhl
# Predicted: iwtetwie, True: powpfyfw
# Predicted: rrrrnvff, True: qylqsyee
# Predicted: qatqvtta, True: otbctryg
# Predicted: cjnjccjj, True: zsagnplj
# Predicted: pdpyuuyu, True: zthxjsxj
# Predicted: eeafoenf, True: pkrkdsnx
# Predicted: xpaxxpap, True: oqpoqklp
# Predicted: iiareire, True: ufkksiit
# Predicted: wwwppwpp, True: ddnlikhm
# Predicted: bfbffpbp, True: dvannxea
# Predicted: cgcgclcc, True: qcmrtxdp
# Predicted: tsnotffn, True: oemfzuqk
# Predicted: ojjujujj, True: uazeqhaa
# Predicted: dtiiitii, True: pkylrqob
# Predicted: btbbbfbs, True: yyprjsvb
# Predicted: iggigcig, True: mdusrccu
# Predicted: pwweeyee, True: hojdgcem
# Predicted: skvfbfbb, True: oqjewdig
# Predicted: fhhnftnh, True: ftpmcaos
# Predicted: iiiiiiii, True: ihwxjbat
# Predicted: hduzcchc, True: whboabsx
# Predicted: kipiikmt, True: tclqchgh
# Predicted: dtddtdyg, True: fnkyjnbu
# Predicted: hfflfzhl, True: vtiyalrh
# Predicted: ghglhylg, True: zqfnwxuw
# Predicted: kkvkvkkk, True: bimyiumt
# Predicted: ihwiwehi, True: hciienev
# Predicted: zzzzxzxx, True: locleucw
# Predicted: nanannnr, True: zujbenlx
# Predicted: haagggag, True: npzkwomm
# Predicted: kykywkkk, True: ghlekttq
# Predicted: vpbzvpfp, True: fnnsicsw
# Predicted: fmmfmrlr, True: wnyyzugs
# Predicted: xxoxxooo, True: oizbmuns
# Predicted: uuuuuyyy, True: mlwgtyoa
# Predicted: axqqmqmx, True: fmioctjk
# Predicted: leelllle, True: iysfxcfv
# Predicted: gncnynee, True: itpwcfkx
# Predicted: ecggecac, True: zoneushi
# Predicted: yjydjgdy, True: tcavccrl
# Predicted: mwjpmwpw, True: bpweppyz
# Predicted: gxgwxnxg, True: eelrdxvj
# Predicted: ssoossss, True: bwzirhok
# Predicted: wrzwwhwz, True: xokmkjjo
# Predicted: czreezcr, True: hhlpfvim
# Predicted: zvzzzzzv, True: xirnydrr
# Predicted: xuuwyuul, True: ojwhdghy
# Predicted: zzzzzzzz, True: kronoxxz
# Predicted: eeeeefef, True: wpuxzacb
# Predicted: ngrvgrgv, True: hztdwmsl
# Predicted: vevvsiie, True: pidaarqb
# Predicted: mdgmmmco, True: xxcuiqgq
# Predicted: ssssrsmm, True: cfhxcbgo
# Predicted: tttiitct, True: ncyfjajs
# Predicted: qeqgqggv, True: xfwehawf
# Predicted: eceecmee, True: hkfdnnup
# Predicted: lplmlmap, True: miovptrp
# Predicted: zzwwbzzz, True: djgwzdlq
# Predicted: ututuuuu, True: nintiujr
# Predicted: ukkuuuuk, True: afvmhdos
# Predicted: vemtbcbv, True: czqmvxgw
# Predicted: rrrrrrrr, True: gqztpnrh
# Predicted: rvyrvyvv, True: kftrlqxy
# Predicted: yaacyaac, True: kxddnfvw
# Predicted: fxtxodwd, True: fhasqdsu
# Predicted: aqqqqyqy, True: meszqwhk
# Predicted: zizrvqri, True: guhnxejt
# Predicted: pyyyyypy, True: cjqxleal
# Predicted: ppzwppzz, True: jtybicpw
# Predicted: wcyycwgn, True: lrrizqpw
# Predicted: bbhjjvvv, True: qqohzuem
# Predicted: jyhbjjbb, True: rgznvmob
# Predicted: ymzpzsms, True: duepdvmz
# Predicted: rdrdrddr, True: jliucxjl
# Predicted: iiizcxic, True: xoxfhkcd
# Predicted: wwwwwwww, True: dynmrsyc
# Predicted: ammmmmam, True: vppiqaye
# Predicted: eggeegge, True: bofglosi
# Predicted: ojappjpq, True: fbqzyqcx
# Predicted: herhwwpe, True: rbgdoomp
# Predicted: crrccccr, True: dyqctpqe
# Predicted: ngangaaa, True: ziwjcqxr
# Predicted: remoromo, True: oeaeysnb
# Predicted: hasashhh, True: wsbqobgk
# Predicted: hoyhhfkk, True: lfqbubsj
# Predicted: feuarfef, True: aaumcuua
# Predicted: bvffsgsg, True: yyihzpkk
# Predicted: ccycccyr, True: hqtntcfw
# Predicted: mmmmmmmm, True: keokvwwn
# Predicted: pfefeppb, True: btkzrkbd
# Predicted: sswwssbs, True: eaapuvgb
# Predicted: nglxxghw, True: zdvwwhgy
# Predicted: mmhgghma, True: lvgdugaz
# Predicted: kkiiienn, True: hqlgnzoo
# Predicted: bblpphbh, True: fhckisbt
# Predicted: vdvvvzxh, True: gxxqpjht
# Predicted: sgsbasgs, True: whppeqnb
# Predicted: gajjagjj, True: rupbzmha
# Predicted: skkkkksk, True: wfqzsdxf
# Predicted: shhshhsh, True: jbbaxrta
# Predicted: phhthiqg, True: vfnugfsu
# Predicted: aaaaaaaa, True: gtrtjlux
# Predicted: mmmdmddj, True: eajwgsjr
# Predicted: nlqlqwlb, True: obualrxp
# Predicted: aaulauau, True: fcmoqvwr
# Predicted: lllllyys, True: jcjtgvdl
# Predicted: xwjxxxjx, True: pfxjwfvs
# Predicted: dduyuydd, True: jbgvhkcy
# Predicted: aeaaaeaa, True: zovegtup
# Predicted: taqttqtt, True: swhbnhek
# Predicted: pbpaxayx, True: zdpkxrzy
# Predicted: foooooof, True: gillbyce
# Predicted: apdmmula, True: nrxxghyr
# Predicted: fvvuuuvv, True: aapvviya
# Predicted: ntujutxt, True: ryffugok
# Predicted: rxrrxurr, True: uqvziion
# Predicted: iaiaiaaa, True: wdijxeji
# Predicted: hhzhvhhz, True: mwuxtxtf
# Predicted: jjjjjjjj, True: qjeiooat
# Predicted: xvzxzxxx, True: hxmlpkyc
# Predicted: jjocjgoj, True: oswkvyrm
# Predicted: bbblbrra, True: vjxflwxd
# Predicted: tsssaasx, True: lmtdtnfy
# Predicted: zkzekgii, True: lcgueqwr
# Predicted: eggwsugi, True: uvxzsuaa
# Predicted: aqisziba, True: kodqpkeb
# Predicted: qkkinkiu, True: bsisegsz
# Predicted: bgagaavg, True: ehnkougx
# Predicted: aaajpndp, True: rvcqgcdx
# Predicted: kkfkfffk, True: wwkruduh
# Predicted: gicggiig, True: delawgid
# Predicted: aaafcfff, True: winesfbz
# Predicted: lblbdlbi, True: ilnhynpr
# Predicted: trtrttrt, True: lrclfapt
# Predicted: dggggggg, True: ugjaossu
# Predicted: tmttmtum, True: lrrdezmp
# Predicted: ffsyyyyr, True: ishsxdox
# Predicted: dzezllzl, True: isqrzjoq
# Predicted: mmmnmmmm, True: rookfihj
# Predicted: oforform, True: oalfhkpf
# Predicted: lbrxuxvb, True: pdhesvgw
# Predicted: ssssssss, True: awjaxvwv
# Predicted: fnoossss, True: mztkgnhk
# Predicted: kaakkeka, True: upqcevkl
# Predicted: vvvkkvkv, True: nypwmkyt
# Predicted: fxeyyrfx, True: mitcuanv
# Predicted: dddsdksd, True: tgkvxnup
# Predicted: ybyqzqbb, True: ffklhdmc
# Predicted: yakggkny, True: yzveorgx
# Predicted: arhhhhrh, True: avtzmgsa
# Predicted: jdahqbad, True: akfzordc
# Predicted: oszeosus, True: nnotaalo
# Predicted: sswuwsuu, True: epvjgtbf
# Predicted: adkspadd, True: mipfqcbq
# Predicted: jjplpjjj, True: qcrdtdam
# Predicted: dddqqqdd, True: zgpfcroc
# Predicted: rrjuupgg, True: muvduznm
# Predicted: ykxlzwuz, True: vglfgpae
# Predicted: tktnnnnn, True: qwudfgfd
# Predicted: fmffffmf, True: jykxasga
# Predicted: pippppii, True: dkfwbjvj
# Predicted: vvgvvvvg, True: lfurqqyb
# Predicted: kykykykk, True: tpcsxapg
# Predicted: aghhihig, True: psijklyu
# Predicted: eesoqsuq, True: kvrcuwdo
# Predicted: crzwuwww, True: ozailciw
# Predicted: buxuuuub, True: tzgsaerf
# Predicted: pccssvzf, True: wormvnzo
# Predicted: xiixhiix, True: jtagktcq
# Predicted: grvhrggh, True: cduuxold
# Predicted: gggggggg, True: qzlnkkkw
# Predicted: zwzzxlxz, True: coxbjokk
# Predicted: cdxnrndx, True: hhnnhpgs
# Predicted: gfofgoog, True: kmqcvfvg
# Predicted: yyyjrhzz, True: qsrrriwy
# Predicted: lnznnjll, True: piopkilz
# Predicted: ygyrmrum, True: qhoimdyp
# Predicted: fmmhhmmm, True: woyyehnj
# Predicted: axxaaaqa, True: zeekayeh
# Predicted: rjbrrvjr, True: uljzuwoi
# Predicted: nmllnnnx, True: qdphpxdy
# Predicted: ziiqzqvi, True: spqravug
# Predicted: vqvttqjt, True: pnupfsxv
# Predicted: zzwzzzzw, True: xjinttfp
# Predicted: ngiiinoi, True: mryhfldm
# Predicted: ggzbzzgz, True: kkfglexe
# Predicted: sqccscqg, True: qjfrfxrw
# Predicted: xcececee, True: yxblphob
# Predicted: aaakkaka, True: saojqyfk
# Predicted: zhhhhyhz, True: zixdkves
# Predicted: umssjjuj, True: wyosxahm
# Predicted: fxrgrrii, True: pgcheddh
# Predicted: dwdhrwrw, True: ztuappna
# Predicted: wpppupww, True: nqremrxw
# Predicted: crlrlrrr, True: igdcfdry
# Predicted: vgqgrfgg, True: pqpjfqgp
# Predicted: cchhccch, True: owtmtkuj
# Predicted: huhuuhuh, True: oxdnfrsz
# Predicted: eoxypqpa, True: qnozzplk
# Predicted: tjfppjpp, True: dtulxtio
# Predicted: qkwiiiwq, True: poylfbpk
# Predicted: snpnhsas, True: mmgqazew
# Predicted: tqhhhqhq, True: jogephld
# Predicted: uuuuuuuu, True: nlnbgiba
# Predicted: yryrfyyy, True: vbgxsfre
# Predicted: nqqnquuu, True: bevsebcx
# Predicted: sshsshsh, True: ahgoazux
# Predicted: hofexbxh, True: twfqjzpd
# Predicted: ndvvvncv, True: nfslhmft
# Predicted: yyyyyffz, True: zpmobmul
# Predicted: pwaawwcw, True: oraclvyk
# Predicted: iibimiib, True: jilwfzsw
# Predicted: eiiiiwcj, True: qtqukouz
# Predicted: ydrberer, True: wqibqgsx
# Predicted: omfooooj, True: unziszor
# Predicted: crrrrrrg, True: ooqpzzam
# Predicted: zzoozozz, True: agklbwsq
# Predicted: gnngutnn, True: zowuiwuh
# Predicted: uwnwrwrw, True: tgvrwluk
# Predicted: bbsssnss, True: wcnyfbpw
# Predicted: iirrirci, True: eiirqign
# Predicted: hxhwhwwv, True: xoebawgw
# Predicted: ylllllyl, True: mtadlkty
# Predicted: lpppopop, True: dgzuzerp
# Predicted: qkeitiii, True: ufgoalsp
# Predicted: vggwwrvw, True: drlslinm
# Predicted: joosjjjf, True: rhgvrmwu
# Predicted: jijiibbi, True: xvvxoxzg
# Predicted: eleflppa, True: jflbexud
# Predicted: qzppzzzp, True: qmbnnhrf
# Predicted: myyrrrrr, True: hvlsrwrc
# Predicted: hxfffxfx, True: nytpdsql
# Predicted: aqsqahzs, True: razhfxof
# Predicted: fpjuiggg, True: lpwmtszo
# Predicted: akkkrarr, True: utaqmyxs
# Predicted: nnddqndy, True: zuwkpjlh
# Predicted: xxxaaxxx, True: mgdcxqah
# Predicted: vvegggjh, True: ltktqlzu
# Predicted: fbbbbfbf, True: wseqenpb
# Predicted: lflmlfff, True: icbaestd
# Predicted: mpjlkjul, True: tbjbwnru
# Predicted: vvvvvvvv, True: hyuyzwiw
# Predicted: zzkkykxy, True: veiqogkd
# Predicted: yjwjjywu, True: dqolphel
# Predicted: ssmadada, True: olanzjex
# Predicted: vnnvvnvn, True: xpdmmhvj
# Predicted: ammmggmm, True: yvvtndox
# Predicted: jmwwjmjm, True: jdsdhwjr
# Predicted: cjcqcqcc, True: ezptzguz
# Predicted: mohhohoh, True: vevksars
# Predicted: amzalmzl, True: xntiqqok
# Predicted: arrfgynf, True: lkpcxnfx
# Predicted: urhuuhqu, True: nmhlvflm
# Predicted: smsmssss, True: wykulkfs
# Predicted: zvvwrwzz, True: rffgklqc
# Predicted: kyjjjqjq, True: gdmdmiqc
# Predicted: guujjqoq, True: mlwhofac
# Predicted: ddidddii, True: gymzbbxr
# Predicted: ooffubbf, True: nclrqmbb
# Predicted: uguxgwtt, True: ydgskyez
# Predicted: ccgggggc, True: lcwfjlur
# Predicted: tkwwiiii, True: ezftqbsu
# Predicted: mpmbaffm, True: bnmpypor
# Predicted: myybrper, True: hbpjjxqe
# Predicted: ognqgoqn, True: zplqbdlq
# Predicted: vbjjbbzv, True: ayvyiqiq
# Predicted: pppmpmpm, True: azdszazr
# Predicted: zzvugzzs, True: iehtsgxa
# Predicted: exexteee, True: hlcugqxr
# Predicted: kkkkokss, True: oxzirdcs
# Predicted: ddysdyye, True: ohiljqgx
# Predicted: favafaif, True: tousprfv
# Predicted: irwgiiwx, True: rwqetnnf
# Predicted: ssmmsmms, True: krflztgt
# Predicted: mhrrmmmm, True: cxqugeal
# Predicted: tttqqqqn, True: zuvyemqh
# Predicted: snysspyq, True: isqvptqo
# Predicted: dbkdwwbk, True: sgtvswgb
# Predicted: jjxtxxxt, True: gqwsawug
# Predicted: iioiooii, True: etavmupd
# Predicted: ekexxxek, True: uyznsmmf
# Predicted: kkkinirb, True: uillhjws
# Predicted: iooifuui, True: amhexxud
# Predicted: thmimttc, True: qqjssjmg
# Predicted: arrrarar, True: zryhzcnv
# Predicted: kwttkkht, True: tzkvnlzz
# Predicted: uvvrrvvr, True: znkiihoi
# Predicted: appaaapo, True: biwnavdx
# Predicted: tgggztvz, True: whqlrrfe
# Predicted: pmwkuuwm, True: jgytctlj
# Predicted: jyjyyyyy, True: rgbvdrun
# Predicted: pypyypyp, True: dgzootyr
# Predicted: xxnnnnnx, True: mqllykkp
# Predicted: hzmhmmmz, True: kwbazhiv
# Predicted: zrggggzg, True: xbwibyru
# Predicted: nvvjqnqv, True: kelbxklh
# Predicted: tmnitaaa, True: ejxmedmr
# Predicted: saaszsay, True: pawcildy
# Predicted: iihhiihi, True: xrgjttwg
# Predicted: duuukudj, True: gexthiqa
# Predicted: fbmfcmwb, True: jfidjquw
# Predicted: qhqrqhqf, True: fzpjscjo
# Predicted: ssaaaasa, True: muznpajx
# Predicted: ahamlljh, True: xgdwkhkl
# Predicted: ntntnttt, True: znwsyitd
# Predicted: egffgegg, True: wfmxecys
# Predicted: ikjkaddj, True: edocmcta
# Predicted: iiewewwz, True: sjrdqgsi
# Predicted: fnfnpfnc, True: fjskgjuo
# Predicted: hhhhxxxx, True: tmlmphea
# Predicted: eacjkknk, True: tzdobylk
# Predicted: moommmii, True: pkqmspne
# Predicted: nsfwywfn, True: zazvpsjm
# Predicted: ccnxxgxx, True: oecwnyhk
# Predicted: uucuccrc, True: hnlmjqnw
# Predicted: egggegng, True: wtnvrwxu
# Predicted: lxjnjxxn, True: zvbtdksk
# Predicted: yycyyyzz, True: uyfueliy
# Predicted: norxinrx, True: pbftzzso
# Predicted: vyjjjiij, True: rvajbemy
# Predicted: qtjvqttw, True: wlgkhyem
# Predicted: iuiukkuu, True: gflhhwmb
# Predicted: nevnnevv, True: emgrxuqk
# Predicted: ycuxxxwx, True: neqoopxw
# Predicted: zzzzzzzz, True: kfvgawwr
# Predicted: yyyyyyyy, True: npvutumd
# Predicted: axiiivvx, True: prwmcies
# Predicted: eeyvryyr, True: rfgxkhod
# Predicted: nlllllln, True: crohkkfz
# Predicted: uvvebeue, True: uksbqjkt
# Predicted: ddnndudd, True: zfcamams
# Predicted: ouuoousu, True: wzzdvhji
# Predicted: rahrhhkh, True: kzrptjuv
# Predicted: ihiiiitt, True: rrhlvjgg
# Predicted: kakwevvr, True: usumdbut
# Predicted: xsyyfffa, True: bgzwhgqy
# Predicted: bpppdpdr, True: jxpokmiw
# Predicted: shbsasaa, True: gmqctcxq
# Predicted: uufuufuu, True: clmisjwh
# Predicted: fmvfffxa, True: yoridbmf
# Predicted: mlmmmmll, True: vcgqtfvf
# Predicted: jtmzlzzm, True: smncctvr
# Predicted: zwhhhrhr, True: gzzuvjae
# Predicted: gtghthtt, True: asjcswcu
# Predicted: qrrrqass, True: wmjjfoac
# Predicted: oqrorooo, True: vmseamzo
# Predicted: vxakfxxv, True: megmebco
# Predicted: aqqqaqga, True: nnbmbbwx
# Predicted: rtrtrrrr, True: hhcgqxya
# Predicted: yzqyyyzy, True: iqqxmuol
# Predicted: wxwxxuxy, True: egygfuez
# Predicted: vuufuvff, True: wmhvldse
# Predicted: ggodggoo, True: mbgitxmi
# Predicted: okqukqqk, True: sbkimvef
# Predicted: bbbrbbrb, True: jlpkxhlq
# Predicted: vbvzbsvz, True: pmhkaqar
# Predicted: obuubuga, True: bhoitbha
# Predicted: pipiiiii, True: hiljhhdu
# Predicted: zjyijjej, True: hhijcmvy
# Predicted: pdspdvds, True: pngjfwfb
# Predicted: vaxdvuva, True: hwttwrlx
# Predicted: yyyycyby, True: jxjotror
# Predicted: tmututfm, True: yqhwggdr
# Predicted: ycuueycu, True: nghsykra
# Predicted: nvavnnnn, True: ztwvnwiw
# Predicted: lfoosofs, True: rsmjwzuq
# Predicted: wwweenww, True: irczlgxi
# Predicted: aaaaagag, True: cxojxhja
# Predicted: uucucccu, True: tgirbala
# Predicted: bfbbkkbf, True: gsoppguw
# Predicted: mmmzzmmm, True: xpbcvvbm
# Predicted: bgggbjag, True: bbnuoblz
# Predicted: gprvgegm, True: ciyxfyui
# Predicted: diiixxji, True: rsfguwlw
# Predicted: mbmbbmmb, True: xrbnfdrx
# Predicted: ofohotqu, True: ndbokneu
# Predicted: ddididdd, True: conuwqrd
# Predicted: iiitipaa, True: kmdmmejt
# Predicted: xuxdxdxb, True: kokwyifp
# Predicted: xyyomlly, True: bdjynine
# Predicted: xruvruxr, True: aszmdzsv
# Predicted: slhslosa, True: bgymupox
# Predicted: uuxzxxum, True: gepafgwf
# Predicted: yyuyyuyy, True: wvuaawjw
# Predicted: ssttstst, True: mffmcfih
# Predicted: puwwwgwj, True: ygxxnjdv
# Predicted: fybmfrkr, True: gaqwifpv
# Predicted: ggiigigg, True: tkdjffjk
# Predicted: raafaaaf, True: uqhlyfcd
# Predicted: laylmyyl, True: uhdfgwas
# Predicted: zntlnlng, True: vovymkxu
# Predicted: wzwzgwwz, True: eoduyucu
# Predicted: kpeeekec, True: glkzjwta
# Predicted: zblzpqql, True: lnpjhsrj
# Predicted: hhfrhrff, True: wbbtafhx
# Predicted: uuxuburr, True: bvwtzgia
# Predicted: wwwwwwww, True: hoadoqam
# Predicted: fjqjjlll, True: wxjqkgbm
# Predicted: hkkhyyoh, True: nnxwgauy
# Predicted: eppcpece, True: hmaqqaup
# Predicted: qdqdddqq, True: swoypgrc
# Predicted: ckkeekkn, True: zpkshobw
# Predicted: gcgcgpgg, True: zlvwvsgp
# Predicted: naanaaay, True: ofpvednx
# Predicted: dxdxdxux, True: zcjzokqc
# Predicted: llhssslh, True: aeycggtv
# Predicted: fkkfkofo, True: yfvezfxf
# Predicted: ossssuuo, True: otnkaebo
# Predicted: vyvywwpp, True: dqzjrrna
# Predicted: bmbhmhmm, True: veijborq
# Predicted: vxxxxxxv, True: wubtpqmw
# Predicted: xaaaaxaa, True: fmrzfdfu
# Predicted: zzzuuuzu, True: aaprdqbn
# Predicted: tttdtyyt, True: vwgsjarh
# Predicted: hxhhevex, True: cfznznja
# Predicted: ppjjpppp, True: rdcdczbm
# Predicted: uuuutccc, True: dozuwyyn
# Predicted: hhhhvvvv, True: vbattnka
# Predicted: mymyyyym, True: stgowdzi
# Predicted: fvffnvyv, True: jvwskteo
# Predicted: xxxxxxxx, True: vkbvcwlz
# Predicted: basbvvsg, True: xltarqdk
# Predicted: burgbgbl, True: oqtyblru
# Predicted: inkiggng, True: cdrahdzf
# Predicted: puqpqqqq, True: bgicqhqh
# Predicted: jjwjjwjj, True: npqtnmom
# Predicted: ndedddnd, True: rbauxwfc
# Predicted: xjrxpxpx, True: qoasllju
# Predicted: gjggjpeg, True: qqdxishu
# Predicted: qhqqqhjq, True: sevexpoj
# Predicted: udktkuux, True: ghbwugrc
# Predicted: bbsbbrsf, True: wafeavui
# Predicted: eeellele, True: pqqwopfi
# Predicted: hhppdhpp, True: ljzwvgkp
# Predicted: mrmmmrrm, True: pqnmsner
# Predicted: didiidid, True: mvulcdnd
# Predicted: nniyifyi, True: chswooub
# Predicted: jmzmzmmm, True: rsxomoir
# Predicted: nfflnnyf, True: fxlterrw
# Predicted: lvccwecv, True: oodkrngt
# Predicted: ikkukiui, True: hrbofhzq
# Predicted: uaauauuu, True: afzfjihy
# Predicted: ibpioikq, True: csmkxafq
# Predicted: jjqnddqn, True: moenauhm
# Predicted: rfhrhhhh, True: uciywdnd
# Predicted: hlhhghrb, True: qkrvwvfy
# Predicted: rilijrrj, True: uivlugqt
# Predicted: rrrrzzjd, True: rfhlfafp
# Predicted: hdhdvvhz, True: pibryism
# Predicted: zwpnnwnn, True: mnfdkeuc
# Predicted: uuuddudu, True: flpkjlgn
# Predicted: oyhyuddy, True: nvrehuyd
# Predicted: vsffvssv, True: aqpjgswb
# Predicted: iqzqqiqq, True: acxtwhgt
# Predicted: eeppwvar, True: ruopnqyd
# Predicted: wopkmcpc, True: uxyubsms
# Predicted: ddgkquka, True: stnqgqcb
# Predicted: iiiaijai, True: bxspcyng
# Predicted: zzzvzvvz, True: meisehzr
# Predicted: fffbbbbf, True: yoqoxocn
# Predicted: kttmmmkm, True: cwrapere
# Predicted: sbsxbebw, True: gmgturmb
# Predicted: ikkkkkkk, True: zsqneiqa
# Predicted: arrerrea, True: bcvhyxia
# Predicted: fnbbbnnn, True: gqbwcjxx
# Predicted: daraddaa, True: vgfaxplp
# Predicted: wahwwaaw, True: hqubbkyn
# Predicted: rrrrrrrr, True: gvtokpsv
# Predicted: uuxzuuuz, True: tfffxurf
# Predicted: gaabceeg, True: uoqoxvnq
# Predicted: yfrfybfn, True: utqiudxs
# Predicted: mmmmmomo, True: lsdnldba
# Predicted: lfcclccl, True: swrooaom
# Predicted: rsreyery, True: hpjclmst
# Predicted: vttotteo, True: tkdxqxzz
# Predicted: rrkrrvrr, True: hbpstqof
# Predicted: msfmsffm, True: npjvsyxe
# Predicted: uuururrr, True: jqbsdvwa
# Predicted: tttttttt, True: lmpdbvhq
# Predicted: ylllyyyy, True: idelsiiy
# Predicted: llqqqlqq, True: skqsvvcn
# Predicted: uugugmuu, True: ktpnzyhu
# Predicted: rrtnnnra, True: dzhfpqff
# Predicted: asppepsu, True: ihklxtji
# Predicted: xysstxin, True: dmccddpt
# Predicted: tntjvtvz, True: ksckxlkx
# Predicted: bffubffb, True: gbujtpjq
# Predicted: yvtwvttt, True: lymwraxf
# Predicted: iciciiii, True: pivmwfmr
# Predicted: tipdiiiu, True: yakpfsqc
# Predicted: zikzzzxx, True: xkvjsyhj
# Predicted: bbssbbsb, True: cchzznkk
# Predicted: arylrrar, True: vavkxsrv
# Predicted: vrvvavvr, True: csfprdxn
# Predicted: csaacaaa, True: vyvcutmb
# Predicted: kjvkkvkv, True: luwnzulq
# Predicted: evevvvvv, True: hvtnaqwl
# Predicted: uwwwwnaa, True: vyxswtbm
# Predicted: aaxaaxxa, True: phrqtecx
# Predicted: uurewwkw, True: efgfpkty
# Predicted: ftmejimi, True: utzcdmzh
# Predicted: avvaavvv, True: eqcgkfkk
# Predicted: usbmmldd, True: shgcwqfa
# Predicted: jbjwietj, True: rmohsziq
# Predicted: pplplppp, True: kovzvaim
# Predicted: jjppppop, True: qaxwqfcq
# Predicted: grrrrrgr, True: lovzspei
# Predicted: wzabwddz, True: lpeesuhd
# Predicted: uuuuiuui, True: zzzaheqz
# Predicted: vyyyecvv, True: poyvrfny
# Predicted: gyfbveye, True: cxpganfs
# Predicted: oyshnpoh, True: djxloigl
# Predicted: yryryyyy, True: vitwqrmj
# Predicted: llllllll, True: btjgafei
# Predicted: arnrlnrl, True: zjdsmzhl
# Predicted: yqnqnyyy, True: mnunjwuj
# Predicted: mdjvmjfv, True: clxwphwc
# Predicted: mmmbfbbf, True: oemjjuig
# Predicted: hhhuuhih, True: ctgfebxd
# Predicted: equqqqqe, True: vwuxbtfa
# Predicted: jjwjjjjj, True: enyupdgm
# Predicted: xbmmbmlm, True: iarfldqe
# Predicted: uukkkngb, True: yoviodus
# Predicted: cddcdddc, True: duoymbwn
# Predicted: uurutrlt, True: huwiqjvu
# Predicted: skksskis, True: whkpxggp
# Predicted: evvjgggj, True: ltuueyxj
# Predicted: occccooc, True: yhiwgibw
# Predicted: wawwwzww, True: fogjnvaz
# Predicted: imjtjbtg, True: rowigxri
# Predicted: kkdadakk, True: wphamiad
# Predicted: siiiiisi, True: nvmpsdot
# Predicted: mmtpmijp, True: leuyipij
# Predicted: qsqqqqsq, True: sgygfzyp
# Predicted: ucwcuvcu, True: kjkqwbop
# Predicted: kozzmmzp, True: kxouxfks
# Predicted: rjtvvgvb, True: oautcehe
# Predicted: xxuknuof, True: nqwlrwxm
# Predicted: zzsgssgz, True: tpfnmkvs
# Predicted: kwaknnal, True: daiufqcs
# Predicted: yepjbjyu, True: ektqshzv
# Predicted: kynjjkjj, True: txnotwkd
# Predicted: ksskskss, True: gwodolzo
# Predicted: hhqoqhqh, True: qcxqvjqn
# Predicted: wwlwllww, True: frhitmha
# Predicted: xxxxfxxf, True: rtiiontl
# Predicted: ffffzizf, True: gpjkkxro
# Predicted: bfbllllb, True: rqavmwwm
# Predicted: pzpcppcm, True: dibemubo
# Predicted: zzkdwzzd, True: oblrrmpc
# Predicted: gejgeejj, True: ytmuaekv
# Predicted: ewgigiui, True: bgoaiedg
# Predicted: aabbbaxe, True: hiostgce
# Predicted: jpjhjggh, True: aokjvpkg
# Predicted: xfuxxgxf, True: cwfftkhn
# Predicted: xmmmmxgm, True: yenipahg
# Predicted: ffrumvzu, True: kzawlvgi
# Predicted: lpbppdfz, True: ogmxikdc
# Predicted: xxxxxxxx, True: gvuygzns
# Predicted: egepdmlg, True: sojwtcet
# Predicted: xzxxllxx, True: vdnjzcue
# Predicted: flmulllm, True: uuevpeya
# Predicted: keexxejk, True: tvlrspuj
# Predicted: zzzfhzbf, True: ppmjncye
# Predicted: hthhbyam, True: vabwjazh
# Predicted: tuapeqae, True: csgqywxv
# Predicted: qbbblupl, True: nhyqiytp
# Predicted: llhyzyrr, True: vlxsukeg
# Predicted: llhhlllh, True: tvnvlwvp
# Predicted: rsyerrsr, True: hearjskv
# Predicted: sqzqjzss, True: lqcpcijp
# Predicted: sbbrrrbr, True: wypwyhtz
# Predicted: qgwwgggq, True: ruxztdid
# Predicted: msememmu, True: hcvbznmb
# Predicted: ajaaaajj, True: zdmaocdx
# Predicted: kknnnokk, True: xwqlwhht
# Predicted: tutzytyt, True: krwqkfyh
# Predicted: mmmksmkm, True: ofatycee
# Predicted: zwwzzfzw, True: kcvwtigb
# Predicted: bfbffiff, True: ekaddsbx
# Predicted: bmchdssh, True: niqvopoq
# Predicted: hhhhhhhh, True: dtccpiel
# Predicted: zzzzzccz, True: wvjyvqhr
# Predicted: mereredb, True: rgacxsnr
# Predicted: nneegeee, True: utebakft
# Predicted: wawedyau, True: poxftlmn
# Predicted: exeeeeee, True: rmgxorzh
# Predicted: ehefheeh, True: eolukmum
# Predicted: aaabbaaa, True: emycciwu
# Predicted: vvvvtffv, True: soloqkcg
# Predicted: buiuksbs, True: ptzbsmqb
# Predicted: hhhkhkhh, True: fspsnajl
# Predicted: umdkpdtt, True: tekefzsk
# Predicted: ixixixxi, True: cukkbozk
# Predicted: yyyyyryr, True: ktvfhxgv
# Predicted: oooososo, True: bizymixe
# Predicted: gggiggga, True: maiuhlod
# Predicted: bmhbbhmm, True: ordrxbyd
# Predicted: xppppxxp, True: lbnvrvqw
# Predicted: nxnynnpx, True: mrnprqkh
# Predicted: vjfksvzs, True: jisojdgu
# Predicted: opoprrpo, True: jlsknbkh
# Predicted: xxxexxxf, True: gojfkebc
# Predicted: ffffffff, True: cipikqko
# Predicted: qhqfhhhh, True: fbasazvr
# Predicted: kkxgkgkx, True: snylkduu
# Predicted: ataaapta, True: zeruxvok
# Predicted: iiiidbsb, True: esnsskvp
# Predicted: ffjffjjj, True: dvnhvbxb
# Predicted: aalvleez, True: csbbmgct
# Predicted: shhhshss, True: pccakeoz
# Predicted: lifuwubl, True: aubnppbb
# Predicted: iittiggg, True: rsxhvpit
# Predicted: zhhhhgrh, True: leopoedn
# Predicted: usqsqqqu, True: snhdlily
# Predicted: cxttchtt, True: dntqdakf
# Predicted: kxkruryk, True: buqucyaf
# Predicted: qbbblsfb, True: iftpduyz
# Predicted: hwxfpelf, True: koljrgff
# Predicted: aannanaa, True: lstawdji
# Predicted: tjrrqrqr, True: hvgozdmz
# Predicted: oyxyjooo, True: bxefqail
# Predicted: idxxhxxd, True: gmkjjtoa
# Predicted: mrumuurm, True: niifsdqa
# Predicted: evaeaeee, True: wlqcukct
# Predicted: vvvfffff, True: wliuxoqy
# Predicted: izuuzzzi, True: nteizyxc
# Predicted: xlyxlbbl, True: gegbltey
# Predicted: vnnvfnvj, True: wxfqgixk
# Predicted: uuuquuuq, True: bjqczmkr
# Predicted: bbsssbss, True: cczjopsr
# Predicted: bpibgngf, True: owbzwtxo
# Predicted: kykynyny, True: gtdpblux
# Predicted: xxxxexxk, True: cyzszzix
# Predicted: jhvhjjyj, True: rjqodfut
# Predicted: plpgglgp, True: dkrqcxxg
# Predicted: nnkckdtk, True: ssatayrg
# Predicted: hxhhhhhx, True: avmydcsy
# Predicted: ffffffff, True: dlfowkeo
# Predicted: ssooyoys, True: knnhsetd
# Predicted: uuouoouu, True: bprkdckt
# Predicted: qqjbfbbu, True: eirncxba
# Predicted: voaxvxoa, True: pjfgptij
# Predicted: xdbdxxxx, True: gtlxkxtv
# Predicted: qtluauay, True: fubgujeh
# Predicted: xdxxjpjx, True: hrnihvtw
# Predicted: susssssu, True: wznzzzpg
# Predicted: vfxfbfbb, True: bllzztzd
# Predicted: czczwwzw, True: ydxstwnz
# Predicted: assaaasa, True: zfgxmglk
# Predicted: cccnicic, True: eybgnzwj
# Predicted: vggvgvvg, True: bffvewtw
# Predicted: lzzllllz, True: imixcncj
# Predicted: mkkqmoqq, True: fkdwwjcd
# Predicted: ynuyzynl, True: zswmhlrl
# Predicted: ididlidh, True: phiugxdl
# Predicted: almldsdd, True: krnstnvt
# Predicted: keeoekee, True: oyryxwbw
# Predicted: ddddkkdk, True: nfxnjvhf
# Predicted: nwcccnwn, True: dgivqekw
# Predicted: gidiiigg, True: ybcjjwmt
# Predicted: uuukuuuk, True: xvebgwfk
# Predicted: ppidpppf, True: ewvpjqdh
# Predicted: epfpfppp, True: bpbzkfqb
# Predicted: eekruxkr, True: orjotmdv
# Predicted: xjjjjxxx, True: tflowntx
# Predicted: nxnnnnnx, True: zvugkoeu
# Predicted: hhkhhnnh, True: jahdslma
# Predicted: xauvvubu, True: ssbcqodn
# Predicted: dshhdsws, True: nldaowgy
# Predicted: vttttiia, True: iuknvcwu
# Predicted: oododddo, True: flimtyiz
# Predicted: vzzzzvzz, True: jyqmdmnn
# Predicted: kkkqqwqk, True: sdgjpyns
# Predicted: izetiizi, True: cmardtyg
# Predicted: ekbnjkww, True: rysamaur
# Predicted: hpiwiifr, True: acdoqrhz
# Predicted: ccirmtii, True: lktgrwyw
# Predicted: xsbfbucf, True: tgnsuoun
# Predicted: geegweie, True: ejtftfax
# Predicted: pppppvpp, True: qamubhra
# Predicted: aaaopooo, True: ofvtbmwj
# Predicted: izwwziqq, True: ejbwybzu
# Predicted: uwwwhhuh, True: nvqcnmkn
# Predicted: olxsybyx, True: vxtdumpo
# Predicted: fnrcvvrf, True: wkoqmbae
# Predicted: ufeufuea, True: kzameldq
# Predicted: xvvevkkv, True: xuxxujqi
# Predicted: nsrbssrs, True: kotksrjb
# Predicted: davraarc, True: fooqmuix
# Predicted: ffxuhxff, True: yzngbdbt
# Predicted: gyaypagn, True: qdzcegkx
# Predicted: gnynyqqg, True: skpulcdu
# Predicted: bmmmmmmm, True: npbvavbm
# Predicted: pkuwwuww, True: dzvhokuf
# Predicted: ubbubuqu, True: sxbnygrf
# Predicted: bbttutrb, True: yuobjtdx
# Predicted: sbtsssbt, True: wccpuvho
# Predicted: llnnllll, True: bxykcowm
# Predicted: sccsccsc, True: wfufncfw
# Predicted: nmggagnn, True: yskukzpl
# Predicted: tbsttbst, True: jxbcjwpu
# Predicted: ydomcqdu, True: ktnowcda
# Predicted: ppgdppxj, True: ggqgfhxk
# Predicted: ecooecie, True: casheqjw
# Predicted: yccypscc, True: czxreefl
# Predicted: vaannzwl, True: bqyecmjg
# Predicted: ugugggug, True: powawdgh
# Predicted: fvdkvdkl, True: tqaqnupv
# Predicted: bwwrrwrr, True: tvwxzcxv
# Predicted: gbggbbbg, True: lmimpxow
# Predicted: lrlnrlnp, True: mjfabzhl
# Predicted: kkckczkk, True: xeulwupt
# Predicted: ejpppgjp, True: ddhxoxuj
# Predicted: yrbdybdr, True: flqpxrdd
# Predicted: appaappa, True: mxabzuox
# Predicted: eeeuaeeu, True: nkukuwrc
# Predicted: itaihhvh, True: pfomxczu
# Predicted: ppptsost, True: zqlwtpom
# Predicted: zmmzczzm, True: ksmwvmhe
# Predicted: iiiiaiai, True: meuyiixt
# Predicted: ibvvzhhb, True: pddjvhos
# Predicted: eeeeeenn, True: kdhywehi
# Predicted: owwowofo, True: jasrtcnk
# Predicted: fuuubfub, True: gzntibaq
# Predicted: mxxmjxxx, True: xektxogn
# Predicted: lxnnexne, True: mmqrozri
# Predicted: qmmrzqmq, True: svvlmwfp
# Predicted: ssggsssg, True: cccszwqt
# Predicted: irgtggtg, True: cyejkbxi
# Predicted: rrfffcrf, True: aiecnhgx
# Predicted: jjwwwjuj, True: nvrbzzrf
# Predicted: yhhvhyhv, True: ccbuyaie
# Predicted: bbuquuuu, True: aolezwds
# Predicted: ooojhoxh, True: natmdhvz
# Predicted: ggygmmyg, True: ipqmgnzu
# Predicted: aafassaf, True: jkklngbo
# Predicted: kurffffu, True: jorhgbnf
# Predicted: cxcckxcx, True: reftvmzs
# Predicted: ppfpxzpp, True: wwjbbhpr
# Predicted: naaaatna, True: sibinctk
# Predicted: qovqqvkq, True: tcqqmslg
# Predicted: lxlljxjl, True: rgfdegey
# Predicted: sskssrre, True: irjiakjg
# Predicted: jujuuuuj, True: bafrmqfz
# Predicted: sssmmsss, True: mjkihyge
# Predicted: mmmmxxmm, True: yiwcdcmh
# Predicted: qiaaqqiq, True: scetrrec
# Predicted: zhzeemtt, True: hbmewkrf
# Predicted: vrvvvvvr, True: cixvcvly
# Predicted: pgagagda, True: mkwkinme
# Predicted: zwwwpwpw, True: oeuvedsz
# Predicted: nwnqnqnq, True: zoasxduc
# Predicted: zzhzzzhz, True: ainepxmr
# Predicted: etcttcet, True: jhtoainn
# Predicted: yiyiggcc, True: vigjdhnu
# Predicted: rjpppppj, True: dfbntppn
# Predicted: jzzyyyyy, True: ecghumud
# Predicted: leghhtbg, True: aruqgbpu
# Predicted: uozvvoqu, True: otuknfiq
# Predicted: kkkyykkk, True: byjjrgsd
# Predicted: zkuzxukk, True: yyavpjea
# Predicted: gmmmmgmm, True: esmdkopq
# Predicted: iiigigig, True: kxtsirij
# Predicted: xcnxccnc, True: veokpkzn
# Predicted: inwwninn, True: ttrbazla
# Predicted: zzwwzzzz, True: imvvnqqm
# Predicted: cjkkkhur, True: nzeefytw
# Predicted: fxffwplv, True: jgcolmos
# Predicted: mmmmgmgg, True: lxcabttg
# Predicted: ttcccitc, True: qallojwj
# Predicted: absbssbx, True: rqflgwzf
# Predicted: vvvkvvvk, True: guhpdath
# Predicted: tqkkkene, True: lstuynqp
# Predicted: ppprrrpp, True: xhuymtce
# Predicted: jdyphiaa, True: mnkzqhbl
# Predicted: gagaagig, True: iejqjsst
# Predicted: lrnrluee, True: usifjqwk
# Predicted: skusfzfk, True: nmmetobb
# Predicted: fflmfmfm, True: xjzthsjd
# Predicted: iyyyyyyi, True: criusgsn
# Predicted: husstuss, True: jmtvlyza
# Predicted: lhohtmhl, True: vbgnlcpr
# Predicted: ffbbffbf, True: nvjqcpso
# Predicted: iiibbiim, True: bwshwqrr
# Predicted: wwwwqwww, True: etxkjpky
# Predicted: rxxarxcx, True: qepvgxle
# Predicted: oiohttti, True: lvvpsdyn
# Predicted: krlkxlle, True: tbmkjfyj
# Predicted: uyyyuyyu, True: edmeatva
# Predicted: vittvvee, True: nsutgsjz
# Predicted: jjriwooj, True: eqttzuvt
# Predicted: iyztetyt, True: pfabqwst
# Predicted: nnqqwnnq, True: mcoleczc
# Predicted: twwwttww, True: tmdebmtn
# Predicted: ggbrgwbw, True: uhwjbtwt
# Predicted: jzjofoff, True: qkapjejd
# Predicted: lppopooo, True: idfeggrw
# Predicted: ckccccnk, True: doixhlub
# Predicted: pxpxxxpp, True: qdgkujpa
# Predicted: jjjpgaxj, True: tfdmyiqk
# Predicted: dcmmnnns, True: yddngwbr
# Predicted: xnnnxnxn, True: voqlyoum
# Predicted: rrxxvxxv, True: cdrxoxbp
# Predicted: mpfxsxsf, True: auzihfxo
# Predicted: qcjucfcc, True: sdyzpido
# Predicted: rufurfri, True: juqyqwyn
# Predicted: oooooooo, True: blfrlaqe
# Predicted: uolsuoul, True: alfiybcl
# Predicted: rfrffeol, True: hajmlzhz
# Predicted: keaqeggq, True: gbqavonx
# Predicted: yjoogyog, True: llccyeoy
# Predicted: jeiekyii, True: pgvzklhj
# Predicted: ckccccck, True: dxcqolrb
# Predicted: ccccrcrc, True: srirtzaj
# Predicted: onanoaao, True: zijcynqj
# Predicted: dnddndnn, True: cirzshrc
# Predicted: hhmmmmmh, True: rkzzlgru
# Predicted: hlhfhlhl, True: wuhksfay
# Predicted: xxxxxxxx, True: rtfyoyrf
# Predicted: mfmomdkf, True: smvfwwne
# Predicted: stsssccs, True: iqolsiqb
# Predicted: ssyllyss, True: idgjzorw
# Predicted: pzdllnhh, True: srzpdrjy
# Predicted: grrrrgrr, True: connpjrh
# Predicted: zblljclz, True: dsgekynm
# Predicted: zmmmzzmm, True: xcbehpbh
# Predicted: hhnnqhqn, True: pzgqfjpk
# Predicted: jjxuxjxx, True: nbpqmqbz
# Predicted: gadqdvqa, True: foruezby
# Predicted: ueyusugg, True: mfsbhbbi
# Predicted: saaasaaa, True: kboygrpi
# Predicted: ctccttee, True: hxtbclbw
# Predicted: iguiutii, True: wjcvbtpa
# Predicted: nnzvvptn, True: nkoromkg
# Predicted: bbsbbrbb, True: wwxmumku
# Predicted: daggagpe, True: hbnjotpu
# Predicted: sstesqtq, True: tedgslpo
# Predicted: yyyybbyb, True: omybgmgt
# Predicted: ljljlljt, True: iegyoyzx
# Predicted: qbrxrbyy, True: ufjrdcfe
# Predicted: aaabhxxa, True: aeewledk
# Predicted: zawvinii, True: riyywfuj
# Predicted: nghgwhgg, True: ixqwagta
# Predicted: paxgpdga, True: vnnuczuc
# Predicted: ssdtdddd, True: skruzmsh
# Predicted: uccucuux, True: nsyuqljw
# Predicted: tttttttt, True: qecmqzfr
# Predicted: vhjjvbjh, True: csethgrr
# Predicted: pkkksecw, True: dwvgobto
# Predicted: ljgrslrj, True: vgpvzgkh
# Predicted: ananaaan, True: mnjrwowc
# Predicted: nnvyxcnx, True: vsryqzts
# Predicted: jgamjgmj, True: lulcxlcm
# Predicted: gtggggtg, True: ynjyjfqu
# Predicted: sbgdsbbb, True: zmwpcynl
# Predicted: zzuzuzzz, True: ycubmzxy
# Predicted: nfffffnf, True: kjzxegwo
# Predicted: rrrrrrrr, True: uaocfmuz
# Predicted: iiapaaat, True: xbccilpt
# Predicted: klkiikwk, True: hkofaxac
# Predicted: bbmmbffm, True: wkmbyfnm
# Predicted: zzzzzyzy, True: ifzvanog
# Predicted: ggggguuu, True: spcflwsl
# Predicted: uuyuuuyu, True: fooacaxa
# Predicted: mmcwcwmc, True: qfthbosj
# Predicted: etvevvvv, True: zrzcnonw
# Predicted: iqiqiqqb, True: pkqhvqod
# Predicted: esgbabsg, True: ykwophcx
# Predicted: qvqqvqvv, True: ftrlcjhi
# Predicted: kyzzzyzy, True: xfroqktp
# Predicted: pggggpgg, True: lybnttgj
# Predicted: cggcopgg, True: okoexfkv
# Predicted: rlslrrrs, True: uicqrkfa
# Predicted: qlgbljlw, True: fhaciasq
# Predicted: rrgiiiag, True: owgfugtg
# Predicted: dausisux, True: jnsyecog
# Predicted: wwwhkbwd, True: bltzbitn
# Predicted: bapbwbwb, True: kpuxvrmd
# Predicted: xxxjxxjx, True: vteokmxf
# Predicted: vvxvxvve, True: hhgvwyyp
# Predicted: kkkfafaf, True: tgjdfpyb
# Predicted: sklkkksk, True: nwwjvxqf
# Predicted: iiwwiiie, True: dmlyarmt
# Predicted: ryrwyyyy, True: etsuzcjd
# Predicted: ekbvkkcv, True: bhbjolop
# Predicted: ndpseids, True: wxgjmiwk
# Predicted: qqdddddd, True: sghzlpwg
# Predicted: exmxwymw, True: bxnnkazy
# Predicted: ncnnnnnc, True: mjeoszde
# Predicted: jbuwqjww, True: wqgctjan
# Predicted: wwwgwcww, True: qnsammyn
# Predicted: ksdmkaas, True: fjdgnhmf
# Predicted: ofohmumu, True: knfazaia
# Predicted: mdmudzqu, True: npyozihm
# Predicted: fffffjjf, True: aqejvnyo
# Predicted: xxuxxtii, True: minhlrth
# Predicted: xyqskskb, True: toxwvpao
# Predicted: tttaaata, True: mtqdatjx
# Predicted: uuxyyxix, True: tabyofmj
# Predicted: oeoooeem, True: afuxjizw
# Predicted: ppjojjfc, True: mnpclxfd
# Predicted: slslxssl, True: okzowpzf
# Predicted: kxkkkkxx, True: suvvnces
# Predicted: rlllzllz, True: hnrhsvhe
# Predicted: eufuenfk, True: yajxgghs
# Predicted: gejegeeg, True: flnqozpz
# Predicted: sufqfquu, True: ilocljpb
# Predicted: taebvaev, True: okmfiiyh
# Predicted: kkukuuuk, True: owauzkyp
# Predicted: juuuuuij, True: ntpmuzdz
# Predicted: pdpppppy, True: dkeuluec
# Predicted: hlhmlhll, True: vifkdsma
# Predicted: caaggigg, True: boslgimk
# Predicted: nndjnjnn, True: snsyvqom
# Predicted: juuqffjo, True: dfjnagsj
# Predicted: eevvveva, True: cfbqndnh
# Predicted: eaeeeeax, True: hvlvlefv
# Predicted: uuubstss, True: gubaloeh
# Predicted: qppoxfft, True: yfnggtmz
# Predicted: nssmssun, True: xnafosel
# Predicted: ggccccnc, True: qhegmbcz
# Predicted: omzztjtj, True: eckriaub
# Predicted: qmgnnmgs, True: enxpdggx
# Predicted: ppaaadpj, True: byvvagkm
# Predicted: elykebbf, True: bhlbyhub
# Predicted: zczddadz, True: stwglovr
# Predicted: sxxxexxs, True: ezgzqirb
# Predicted: rrrehwgy, True: anehxdol
# Predicted: hnccccch, True: xnexftfx
# Predicted: vvvppvxp, True: xdpukkym
# Predicted: pdpbpbss, True: mvnpmioc
# Predicted: zzzzzzzz, True: frgafrcj
# Predicted: rrpdlpdr, True: skssxcqv
# Predicted: ukukggkb, True: bmtzpcan
# Predicted: mgmmgmam, True: kbaufyki
# Predicted: zjmxfxzm, True: jxsljklp
# Predicted: mssxmxms, True: ejwsaqpu
# Predicted: puuicicz, True: xystkdqw
# Predicted: uaquavaq, True: smobkcbm
# Predicted: cjjjiucu, True: qdmoypkn
# Predicted: biiyexbx, True: bhxjlheg
# Predicted: iihihoii, True: lediftnn
# Predicted: btbbjjbb, True: lerqfoum
# Predicted: zdzddzrr, True: vsixfxvc
# Predicted: ccrxrcnn, True: fyomcsvo
# Predicted: oooooooo, True: rkzqrbaq
# Predicted: qxsqssqn, True: jlccwtam
# Predicted: uhuuuuww, True: uniunmaa
# Predicted: dqddddqd, True: faukujip
# Predicted: kkpkkkkp, True: qdnxxzar
# Predicted: ululuuuu, True: abnggngt
# Predicted: oxououxo, True: buamxydd
# Predicted: uuujbbuu, True: gsirwerq
# Predicted: aaaukuug, True: aigwrtnk
# Predicted: eppppppe, True: lbceqafv
# Predicted: ssfssssf, True: ixhtblwb
# Predicted: iimrielr, True: hvfmvxbi
# Predicted: uzzlubbb, True: iyrvsewn
# Predicted: pprrpppp, True: fvsajtvi
# Predicted: ennyekne, True: teffeyui
# Predicted: oxoqgjxo, True: pqhykeop
# Predicted: eeeeeeee, True: xcqeepkd
# Predicted: bnocmaoa, True: mibtwcsd
# Predicted: bvvbfmff, True: xuawpbig
# Predicted: nnintnit, True: pkhoricu
# Predicted: bfbbsssb, True: nejlcmzd
# Predicted: xmxmxmxm, True: wsulylyr
# Predicted: fflblfaf, True: lrdswwxf
# Predicted: sbmssmss, True: gsgvmbbe
# Predicted: xkdkvkyv, True: cibyskkc
# Predicted: geegisgg, True: pbnwfjng
# Predicted: azczzizi, True: qypbploq
# Predicted: fbmmbrmr, True: wuizseoj
# Predicted: nnxnnxbb, True: owewclxv
# Predicted: dldldkll, True: swupqfif
# Predicted: sszzsszs, True: xxatxnnb
# Predicted: kcikkckl, True: gpexkbcw
# Predicted: fiffbbzf, True: krgqpceq
# Predicted: gvbbgggb, True: ebcelshd
# Predicted: eiitteof, True: jzvvwkot
# Predicted: mpptpmqg, True: tmbnuevr
# Predicted: fjppbpmx, True: wguftutj
# Predicted: uqmpmqwy, True: kprcpbuc
# Predicted: dydyyggq, True: sphmhifp
# Predicted: bbzgzbgb, True: lfuljaxt
# Predicted: glgegegl, True: ynuxwfmi
# Predicted: zkzzpqip, True: dwxuhdrr
# Predicted: fufhuhuu, True: zoxeajcb
# Predicted: riiriirr, True: hvgdbght
# Predicted: dnbddfbd, True: pvkllghp
# Predicted: jjxxlxkx, True: galywuai
# Predicted: bsbsbbbs, True: nmpqcepw
# Predicted: mmxmvmmv, True: fzejwkgf
# Predicted: bjmxtxbx, True: gptpgott
# Predicted: etvueetb, True: bqbhwfgy
# Predicted: xjccbuuu, True: vcpwicps
# Predicted: iizfzzzo, True: xacwixzq
# Predicted: gtvakgkv, True: cghlwcdk
# Predicted: fyffkfff, True: zatlpjyb
# Predicted: mzzmmmmz, True: kigozicr
# Predicted: cccrcrrc, True: rrhdoofw
# Predicted: mshymhhm, True: bywzpers
# Predicted: mmfffffm, True: wqljpzcw
# Predicted: fqkplfdp, True: dfocubko
# Predicted: fftfftff, True: rdbppnxr
# Predicted: eeeeeeee, True: kuvbupfi
# Predicted: rrrrtrrt, True: hpvspyaj
# Predicted: pmompmmp, True: gavbmugj
# Predicted: vfvllffv, True: cocsqdbt
# Predicted: nnqssnqn, True: scbmjngj
# Predicted: gbgbghgb, True: lvjeuroc
# Predicted: uguguugg, True: kdhmuzhe
# Predicted: nudmundn, True: ipuwynwx
# Predicted: aapapapa, True: krjzwwlx
# Predicted: bbbbbsbs, True: vnrxtzrx
# Predicted: elaaftep, True: kvhdvjih
# Predicted: aaataati, True: zbjiashx
# Predicted: hhzeeerh, True: hjiqbxgr
# Predicted: ggpgvvgg, True: uinrzxiw
# Predicted: sssososs, True: jtxjkjob
# Predicted: vnxteiiw, True: phmbkkeh
# Predicted: kikkexef, True: gdojacrf
# Predicted: xxhhhxxh, True: aagnfitr
# Predicted: gsvaeqsq, True: szjpmkbx
# Predicted: zzlpzlzz, True: wgtumhmu
# Predicted: vvnvcvvc, True: fzcrzjzj
# Predicted: sqqasqqa, True: mlugmbwx
# Predicted: rrrrrrrr, True: uowhceih
# Predicted: efoyffmm, True: xtntifdg
# Predicted: fiktfjkt, True: tgolwunh
# Predicted: wewwwwee, True: kyrghizm
# Predicted: ffwzzffw, True: ecvsvtfc
# Predicted: lkkklkkk, True: vffgwavl
# Predicted: ssosssos, True: lasjquco
# Predicted: lwiwmkim, True: vlbgywme
# Predicted: aryyrnyy, True: iwodiruv
# Predicted: dkddhssk, True: vfujujfc
# Predicted: xkxxkxkn, True: wgnqjlqf
# Predicted: mmkmmeem, True: gxfrxlkr
# Predicted: ccgcgcgc, True: qplmyznw
# Predicted: aeeeaeeg, True: puurboqf
# Predicted: smsrmrii, True: jgrgysze
# Predicted: nsnsnsnn, True: otpwjqoo
# Predicted: mvmcxzvm, True: fmmioxkd
# Predicted: stttsstt, True: nfvwwpqy
# Predicted: msttmmtt, True: lgtayler
# Predicted: esfmxxfm, True: wzmfjicz
# Predicted: zzllzzzz, True: wwlmgqkc
# Predicted: vvhhvgvh, True: bpczmqih
# Predicted: tteenete, True: uktegjjv
# Predicted: pgipippp, True: fxdzyypg
# Predicted: vfjffjfv, True: ucctresg
# Predicted: zzzwzwzz, True: aaxtbihb
# Predicted: vvvvvvvv, True: sxepqunt
# Predicted: oiogoogg, True: nmoriiiq
# Predicted: rrdbbhlv, True: oempjvyi
# Predicted: rxhxhraq, True: uluxqafh
# Predicted: jxakkaak, True: qgvtqkyh
# Predicted: uukukknk, True: qdphetvf
# Predicted: wjwwwjww, True: rxzpexpq
# Predicted: muhhhuvh, True: chwxwblr
# Predicted: lwcllllw, True: vamttrez
# Predicted: uuuhhuuu, True: yguafwib
# Predicted: enrjespr, True: scmiytco
# Predicted: eervesre, True: pghsxyei
# Predicted: rksrykys, True: wgqybmcv
# Predicted: vlbvfdfq, True: wvfxndfc
# Predicted: ssvrsvvr, True: mrztbyab
# Predicted: cxqxnucx, True: sdopgasy
# Predicted: hhthhhdh, True: yfzlvzla
# Predicted: knnnnnkn, True: tpqazghk
# Predicted: wjwjjwzm, True: aqbouwce
# Predicted: hnhhhhkk, True: swbqzsta
# Predicted: vzzvvzov, True: pcjslvxr
# Predicted: ppippiew, True: xduqmmym
# Predicted: lnhyhhll, True: zvvfplia
# Predicted: oqoddzqf, True: jbpzimal
# Predicted: mtaavvvv, True: zbzdrmiy
# Predicted: teeeteee, True: lhveekgg
# Predicted: ttnfttft, True: meizkseh
# Predicted: uodumouo, True: nmbyqwtq
# Predicted: imiimwmw, True: rzwmtcij
# Predicted: tlllalaa, True: icjjuqvy
# Predicted: kkkddkkk, True: sbijcegk
# Predicted: dndnmdrd, True: fduotzta
# Predicted: oteeohte, True: pttoboni
# Predicted: kskslkos, True: tnnnxmko
# Predicted: vjcvbvei, True: jheodoxy
# Predicted: bgnnnmgg, True: bjyrwqjk
# Predicted: ukkkbkbb, True: odinplwf
# Predicted: gqgqygyd, True: ihuatswu
# Predicted: ggjjgttt, True: ygkpugsz
# Predicted: vtvwwvvv, True: upxboehh
# Predicted: qodqdtoo, True: ydcrkdpn
# Predicted: zssvlqml, True: fitobnao
# Predicted: iiekewii, True: gzfdpmja
# Predicted: ffpfnnnn, True: zkjetwrp
# Predicted: czzlcldd, True: dqgvoomk
# Predicted: ukgykgku, True: anyaagql
# Predicted: sbtbssbb, True: ppdmqstt
# Predicted: tqttqqkq, True: limnesrv
# Predicted: bztiiizb, True: hfiukscq
# Predicted: kkkkkkxx, True: tcwxrbvs
# Predicted: iiwgwowi, True: absuybfu
# Predicted: jscjschj, True: lpuprsqo
# Predicted: fxdxjxii, True: plwjypzm
# Predicted: mmsmsmmm, True: japbxicz
# Predicted: ajjjpyba, True: iynxxpuk
# Predicted: wxwwfuwf, True: weqjjmaa
# Predicted: aonoagao, True: xccswmsd
# Predicted: zozzbozb, True: xrsbnfft
# Predicted: csuzzvtz, True: xzunmuwt
# Predicted: sasaasss, True: wjlbruil
# Predicted: zjhtjdhf, True: ygtptgoe
# Predicted: nixbilin, True: xfwsimhd
# Predicted: cewqxppp, True: rvcvxbkc
# Predicted: esseesee, True: uvwekhls
# Predicted: asaassga, True: ejkggggb
# Predicted: cccwxwwc, True: vnbnphjj
# Predicted: fotfofot, True: csupbxvb
# Predicted: lkklllll, True: vhrsslfj
# Predicted: ttittilt, True: esywijcw
# Predicted: jjmmwwwm, True: reqewmvi
# Predicted: gghgjjgg, True: hwicyucn
# Predicted: cxxxrxxr, True: hhmoylas
# Predicted: ggbgggbg, True: bmuytxfh
# Predicted: jbbbbbjb, True: uxzykkzq
# Predicted: zvzzzzvz, True: kybfmdar
# Predicted: gggggsbz, True: gvpcfmlh
# Predicted: dudvuvxd, True: twffscew
# Predicted: gjguuggg, True: gjqlyybz
# Predicted: yyuhyuuh, True: nielaiuy
# Predicted: rrdrrrrd, True: fxipxijn
# Predicted: nvvvanva, True: dlgtqfzk
# Predicted: hmmqoooh, True: wqbrstde
# Predicted: vvvvvvvv, True: pslrfvtg
# Predicted: rrrrrrrr, True: hhwldpui
# Predicted: vvvaysva, True: xwgrfeml
# Predicted: kkzkzzzt, True: xxoofjwh
# Predicted: iljvllzi, True: kiqczbwt
# Predicted: gljgujul, True: lwjybltz
# Predicted: ssssosoo, True: emeycawo
# Predicted: ffavfzaa, True: kivylttg
# Predicted: ihehhhhi, True: ferkavvq
# Predicted: kcckcktc, True: dwrlbwpg
# Predicted: tbubtttu, True: llsdgnva
# Predicted: yqmllvte, True: ccbbsofc
# Predicted: huhhuhhh, True: asthoayn
# Predicted: hhhhwpph, True: mtbuzwln
# Predicted: kmkoooqk, True: jqyjpnyl
# ...
# Predicted: tufzuutu, True: jxfplhbn
# Predicted: iitttuit, True: yxukcnkr
# Predicted: ikkkkpkp, True: sigifwlg
# Predicted: qxxuquni, True: spixeull
# Predicted: wdwdddww, True: eiztansd
# Predicted: sisgfxso, True: laqugwyf
# Predicted: ogggyqog, True: aqscxbfu
# Predicted: fzyfzzzz, True: vnvpmnkr
# Predicted: xexjyyxk, True: cnmffzuz
# Predicted: yyzyzyyy, True: erxgrpqm
# Predicted: uuujujuu, True: rsmhnuyd
# Predicted: axaxddax, True: zlwmxarc
# Predicted: mysssnss, True: xzksbcjm
# Predicted: rhhrrggg, True: hbetiuza
# Predicted: hnhmmzhh, True: txfdvexr
# Predicted: yqqyqqyq, True: xllwddwp
# Predicted: ylxylyyy, True: vrtfbneg
# Predicted: hzaautaa, True: yzocudxe
# Predicted: hwdgahrh, True: lttnipra
# Predicted: cuczuuuu, True: onndohhh
# Predicted: joajpcap, True: czjcbbfz
# Predicted: yddyduyx, True: dxptkqcp
# Predicted: cgtggigt, True: uplcjwph
# Predicted: rrrrrrrr, True: urnrwzbd
# Predicted: kmmmmbkm, True: gsoyrvhe
# Predicted: ltououta, True: buymtyrd
# Predicted: yzyzyzyz, True: vrgyqfke
# Predicted: bccbtbcc, True: bwbhxjid
# Predicted: abbuusaa, True: wpstlbed
# Predicted: eeeaoeoe, True: dddihaut
# Predicted: ssmuksss, True: kbiiavcn
# Predicted: auauaugf, True: yugipwmb
# Predicted: mgffhfff, True: jelsdjks
# Predicted: cccwwcww, True: aeqtjptj
# Predicted: khoqcpkk, True: bwqdfxsj
# Predicted: xixixiii, True: filfuozz
# Predicted: zszvzzvz, True: naxutbvr
# Predicted: gxggmxgm, True: xxvneaaf
# Predicted: nxnwxxxx, True: flsrzonz
# Predicted: wxexwxxx, True: hwcfgllf
# Predicted: pjlvhllv, True: ikckcvjt
# Predicted: zezzzzze, True: krvrfqcv
# Predicted: upkszquz, True: wslsrfgz
# Predicted: ssrsrsss, True: bqkkpxeo
# Predicted: jwwjzwxj, True: exhwpyfx
# Predicted: dddaddad, True: chyuocbc
# Predicted: duutuuuy, True: wyyzjxfl
# Predicted: qsgsssso, True: sjmuzeuu
# Predicted: uxxutxbx, True: nttytcoz
# Predicted: frrrrxnm, True: xslkhqgu
# Predicted: hzzhhhzh, True: lrqgyfka
# Predicted: xuuueueu, True: bdsfanqn
# Predicted: ffuufuuf, True: idjajbtb
# Predicted: mxmmgmgl, True: xcpnkfcg
# Predicted: lldddqdl, True: fdkkcwrl
# Predicted: zxdxbzbz, True: qckwqugc
# Predicted: lpldllll, True: dqevocya
# Predicted: regrsggg, True: vbjhobez
# Predicted: kkkkkkkk, True: jfhsliox
# Predicted: ppppjpjp, True: emgqcmlj
# Predicted: hhgglohh, True: qqcpdrph
# Predicted: vwvwbqvb, True: pevywcrq
# Predicted: yyykkyyy, True: ploquenf
# Predicted: ifxifxix, True: gedhtezr
# Predicted: ygnynggn, True: pceqtfsw
# Predicted: teeeette, True: mvilbbhi
# Predicted: rvrjvxvx, True: uioxvtai
# Predicted: kkkkkpkp, True: pmjppbyp
# Predicted: wewvovzv, True: xpsdkfmd
# Predicted: mmmmmtts, True: oulgvacr
# Predicted: kekrkrvx, True: fdpagplv
# Predicted: mxiimxii, True: xkxlhswz
# Predicted: jngncsnh, True: etzmfcsy
# Predicted: wykmckyy, True: gtnrpusv
# Predicted: xmjfdaaa, True: zvuhyxap
# Predicted: wwwwwwzw, True: xuvojfik
# Predicted: nhhnhnhh, True: vzlgaqig
# Predicted: dxvvtdex, True: smvrmzxu
# Predicted: lcnnlmlc, True: zrhopniz
# Predicted: zzxzxzzz, True: tnsoyjic
# Predicted: vjjvvvjv, True: ayrldrft
# Predicted: aajuuaja, True: reytlxun
# Predicted: ppppzzpp, True: ttauetiw
# Predicted: xllxxjjj, True: sztzsuae
# Predicted: ggdgdmdd, True: fauepciu
# Predicted: nhnlnhfh, True: ioiavzkx
# Predicted: kokookoo, True: teyltcvm
# Predicted: ffmmmbam, True: kssrzjas
# Predicted: nsnsssnm, True: tardyhme
# Predicted: lqvllvla, True: pvfqsgsm
# Predicted: tnntnntn, True: dlvvvbck
# Predicted: yemyxleg, True: gjmrdtot
# Predicted: uiiiuiii, True: fggppclo
# Predicted: anigaigg, True: misijpgb
# Predicted: zqzqqysq, True: rukvdcwr
# Predicted: aavvvvaa, True: bqcnelkg
# Predicted: agedgppu, True: mnahtcpa
# Predicted: ssgdsssd, True: hhrafwit
# Predicted: cccquccc, True: ahqysogp
# Predicted: rrrrsrds, True: wybysgwu
# Predicted: kdaakapa, True: ydzhvwkx
# Predicted: xxxnnxqn, True: qdcltxjk
# Predicted: nqndnqqq, True: fcdupgym
# Predicted: eeevvxvx, True: tzmmucbv
# Predicted: ctttkkvc, True: kxkduarp
# Predicted: kdznhzfz, True: wftzzdkx
# Predicted: gggggcgc, True: ghvzhmfw
# Predicted: scjhjczs, True: lermvmzb
# Predicted: kzwkkwzx, True: avujsfus
# Predicted: zzzzzzzz, True: mqgoymxl
# Predicted: cpltchtt, True: akmysjow
# Predicted: nneykykk, True: uvuajysa
# Predicted: oooooodd, True: fcaczvld
# Predicted: iwkpkypw, True: srinmkgm
# Predicted: xnfgdxxn, True: werbujzm
# Predicted: gjgjaagg, True: ktqdvyez
# Predicted: njjsnspa, True: eadfloca
# Predicted: xoxooooo, True: grwqfrem
# Predicted: jiwjwiww, True: gqwoganv
# Predicted: vrvqgrdp, True: dahbweyo
# Predicted: kpyykkkk, True: urbxmfyw
# Predicted: yylgyblg, True: bolzjyxy
# Predicted: jvmllyjj, True: qdacbibr
# Predicted: wwbnwnbw, True: uhxlzoez
# Predicted: phxhppsw, True: jtsdzmqi
# Predicted: pjpjjppp, True: pvjczjna
# Predicted: uuhhzxhh, True: jchffxsr
# Predicted: yicywyww, True: izycqfix
# Predicted: xtttxttx, True: vmfobaqs
# Predicted: nfnnfnln, True: zafdttcb
# Predicted: buhbbubb, True: bxgxxnoa
# Predicted: moovoovo, True: lkvgthyq
# Predicted: ivxjbivi, True: saismvgg
# Predicted: yyyyxxyy, True: dtcxaqqp
# Predicted: bfgffbag, True: rpyomwht
# Predicted: xhxhhxhh, True: gultakup
# Predicted: xvxxxxxv, True: gykwnlng
# Predicted: gevgbeve, True: bggwifux
# Predicted: lmwmnimw, True: rddfrdec
# Predicted: qwwwqzzq, True: ftuhgwkn
# Predicted: qrurqqrq, True: skuzxryc
# Predicted: wlwxlwxw, True: tpqcctcq
# Predicted: ccpcccps, True: debnapiw
# Predicted: uttttutt, True: egpkubrd
# Predicted: wszssssw, True: ekjorejm
# Predicted: yayraldl, True: iwxjkbif
# Predicted: vmvgyyxx, True: lmpynbqc
# Predicted: qrqqrqrr, True: sqjmgpmo
# Predicted: haffaafa, True: hyhktxlr
# Predicted: ukbekukk, True: bsdbtkhi
# Predicted: xxdddioy, True: srkczurf
# Predicted: fknhkhhd, True: icicpgqf
# Predicted: hhsstshb, True: rzukkkkq
# Predicted: acwuyawn, True: ahjksalw
# Predicted: srfirvyf, True: pfgtwpwb
# Predicted: kbswskbj, True: wcpalsjs
# Predicted: nwnenwre, True: zjlstlni
# Predicted: eeedeyss, True: wzathqwv
# Predicted: yjuuyuuk, True: ytyssxne
# Predicted: xggxxxgx, True: cctkiijf
# Predicted: uvjvuuuj, True: fgnclazv
# Predicted: bbsssbbh, True: wfwzbjxo
# Predicted: sbbbbsbs, True: fyvhgfem
# Predicted: aboafiyi, True: mumtvdhd
# Predicted: wffwmiiw, True: kltityqe
# Predicted: gucgcggg, True: adqfauga
# Predicted: cjcjjcjj, True: ddwasnhr
# Predicted: pyppypyp, True: dyfuwmvw
# Predicted: xxxxxxxx, True: yyamwytf
# Predicted: bddfdfet, True: ljmcugjj
# Predicted: ccekwwer, True: pdocbzpm
# Predicted: pxayxaxy, True: decxynuw
# Predicted: vhehehvh, True: zbnnqckt
# Predicted: ibbbmtic, True: cwvodrcj
# Predicted: wuttuuuu, True: rkztdqgh
# Predicted: pplppflp, True: jhryejmw
# Predicted: wnnnnwkw, True: tomqhucy
# Predicted: gqgwylnn, True: wfmzzygl
# Predicted: oyyooyoo, True: ozifdlzc
# Predicted: scccssss, True: wfxzfhkn
# Predicted: ppxcppxc, True: dhgpxirj
# Predicted: yaaaffaa, True: vjyizrgv
# Predicted: ixuxuyff, True: ojcwtrdf
# Predicted: kgjfakjk, True: tvgguayu
# Predicted: hwpqaqwp, True: mmvuknwc
# Predicted: nnynnynn, True: bxaoqfgs
# Predicted: xryxxjtx, True: gkvjenxi
# Predicted: uputqpuj, True: nbrqzmqp
# Predicted: wwiwiwii, True: ckksdqyb
# Predicted: mmmfmsms, True: tqmksvov
# Predicted: alpggula, True: dowmyjpw
# Predicted: zzlzzzlz, True: giiyesce
# Predicted: awppaaww, True: dwajfpru
# Predicted: ggaeseas, True: udofwvyu
# Predicted: deeddlde, True: fpjuedpl
# Predicted: ennfanci, True: zannshlx
# Predicted: yzyyyzyz, True: vzcxhktf
# Predicted: uuuuuull, True: wzhollsa
# Predicted: dysyddyh, True: nvexifqv
# Predicted: ffnninnn, True: mgrlxtjt
# Predicted: evnvgage, True: zcieofxe
# Predicted: eqbqqqbb, True: bftxxxsi
# Predicted: yykyyqky, True: sntdokfl
# Predicted: uududuuu, True: fgqnzaza
# Predicted: ytytyttv, True: xfhswwvt
# Predicted: zzzzzzzz, True: krrixjzh
# Predicted: qqgqgqgq, True: nmyiskvc
# Predicted: rrrqrrrr, True: upgwnspr
# Predicted: eqqedqeq, True: wmgykadp
# Predicted: rrrrrrrr, True: yknumcfp
# Predicted: bbffffpx, True: wevfobvq
# Predicted: htwutwuu, True: npeuknka
# Predicted: lrrldppu, True: qicnnudv
# Predicted: qqittiqq, True: lggzptat
# Predicted: ggavvggg, True: mgieydko
# Predicted: rorrrmtm, True: lrcgsnwe
# Predicted: xexxeexe, True: tcrxxfjk
# Predicted: ooxooooo, True: djkarfwd
# Predicted: zorzvzrz, True: xylxjzut
# Predicted: tcccwtwc, True: rlpxdmtj
# Predicted: uubbqbun, True: idubdcyx
# Predicted: bbbgbssb, True: jaombpbl
# Predicted: iiniiiin, True: doxvcczb
# Predicted: hebweddh, True: kaftdzhn
# Predicted: pppmmppp, True: hklphgcr
# Predicted: ddtddddd, True: fjeqedsc
# Predicted: syrngcrg, True: mdubpddi
# Predicted: fffifjjf, True: zwkzqulb
# Predicted: rgmomroo, True: kbcbcytj
# Predicted: vwemvzzz, True: xstiyfqf
# Predicted: wjvorjwj, True: orkxzxzm
# Predicted: wqzzzwuw, True: atruegml
# Predicted: ssaaaaas, True: mtildwap
# Predicted: swfizifz, True: cbcilfgm
# Predicted: kiikiikk, True: xgirfnhw
# Predicted: xxqhqhjq, True: zlcudeds
# Predicted: hlllhtll, True: gwicllxa
# Predicted: mssshmms, True: trcrpveo
# Predicted: pppttpps, True: rdpgcfdb
# Predicted: oeeooeoe, True: obxxecsi
# Predicted: xxxnyxny, True: ehftvopy
# Predicted: eehehaeh, True: aozkauqk
# Predicted: znnpyzxy, True: iyrmicgk
# Predicted: sywhshwt, True: qpakqgmb
# Predicted: lhkwblbi, True: rjsvuxty
# Predicted: tdrdtrar, True: xicptljc
# Predicted: keakkkye, True: qjrwbjis
# Predicted: tttatatt, True: zaimfnxt
# Predicted: hhshllll, True: idtylkpb
# Predicted: kkkkikei, True: hqxzorrx
# Predicted: drdfxxrj, True: lxotzigs
# Predicted: gttittgj, True: ejujjuru
# Predicted: smmsssss, True: whwoobtq
# Predicted: gbsshggb, True: lmsihkdv
# Predicted: ssbsbsss, True: zoqxgrpj
# Predicted: ntttltyn, True: gaubfjsu
# Predicted: ngnucunn, True: qliijzxp
# Predicted: jzjjzzzz, True: dbqwytkm
# Predicted: dwwzgzzu, True: xeeuqqhq
# Predicted: mhthvqmh, True: pucozezn
# Predicted: keeekeee, True: qxpnmwfd
# Predicted: ssstssss, True: wawqhlve
# Predicted: uurrqrus, True: wcaixuho
# Predicted: lllbqlll, True: ouxonedy
# Predicted: bdmmmmbm, True: kglbbzbp
# Predicted: bxixxuew, True: hcubzumz
# Predicted: xnririxn, True: iodooums
# Predicted: iirirrii, True: uxpykfex
# Predicted: tthtohnr, True: umqozcoj
# Predicted: ububuyub, True: jbbxpyvl
# Predicted: pqqpooqq, True: ogipdpas
# Predicted: haamlzxh, True: ueuxdsaq
# Predicted: suussuss, True: mnxscmda
# Predicted: yaeyadyd, True: ibdekkgt
# Predicted: bknuhlkb, True: albrnkmn
# Predicted: aaaanaan, True: zfsptvxh
# Predicted: lnlnllll, True: vctemywx
# Predicted: ssppsspp, True: ufgyxnao
# Predicted: ihhhhhhi, True: jfzgkbjt
# Predicted: ssbbkeos, True: uzrcsofu
# Predicted: yyyyzzyy, True: qzgumheb
# Predicted: aaeaaeaa, True: xqacawli
# Predicted: yyyyynny, True: kzhwercl
# Predicted: iffffivf, True: pdgtjdtj
# Predicted: ueucnueu, True: afoipijn
# Predicted: oegeoveg, True: pstlbudu
# Predicted: zhhzhzhh, True: sscoadlx
# Predicted: lrrhhhrh, True: aapxpyea
# Predicted: ggggmggm, True: vfkcoeke
# Predicted: xuuquqfq, True: lxdxcrdg
# Predicted: mmmmnlml, True: xdqrumov
# Predicted: rrkxrryk, True: vrzoslnf
# Predicted: bbbbbbbb, True: oehlthxb
# Predicted: ppkwlwpd, True: rgxszbff
# Predicted: rrrrlrrb, True: obwlsvug
# Predicted: rwrrrzrz, True: tjlsmvcc
# Predicted: iztiiziu, True: bdrhuror
# Predicted: zzzqzzzq, True: gmcgjemp
# Predicted: lzyddllv, True: ietgific
# Predicted: tttiinii, True: zfnvlszh
# Predicted: ccinalan, True: fuseipfk
# Predicted: ernnennr, True: hufqleqi
# Predicted: kkzkzkzz, True: kftytaay
# Predicted: pnpzpzvv, True: xthkmqik
# Predicted: tttttttt, True: ywcswiqq
# Predicted: hyvhzvvy, True: avrojsrv
# Predicted: ffnfnndf, True: uwuyglnr
# Predicted: uiququiq, True: sknzzscc
# Predicted: rmmrmmmm, True: fvzvltvp
# Predicted: gvmrvmbw, True: yvngtkyg
# Predicted: lccgyygc, True: yjxwrjyw
# Predicted: nggnnggg, True: qwubtqcc
# Predicted: ppjjoajp, True: mmntnfxj
# Predicted: oofooofj, True: eniamsqd
# Predicted: dxxhxxdx, True: wsjlvaws
# Predicted: wrnwymww, True: vgbcattk
# Predicted: qqqfffff, True: wwtfixkt
# Predicted: ggwwwgvg, True: pelsclvm
# Predicted: vvaaqvvv, True: eubwkvek
# Predicted: ioiooioo, True: reophvoh
# Predicted: expppppe, True: hsvafqss
# Predicted: sssskzzs, True: mryimsyb
# Predicted: xxqbihqd, True: xvwpvehz
# Predicted: kkckkkkk, True: gaiuknjh
# Predicted: vvvvjkks, True: gzvbyixv
# Predicted: ldddqeql, True: ijqupoum
# Predicted: cniciici, True: mjweaakt
# Predicted: mibitbtu, True: nfkiclyc
# Predicted: hfhwjhhh, True: tksxrrvy
# Predicted: naaidatd, True: ffzjjjbt
# Predicted: dvvdvvvj, True: sdrvjhzy
# Predicted: iixgigxg, True: ldtbmbmx
# Predicted: cgcugcci, True: dslxtmsj
# Predicted: apcpasas, True: muwxpfxb
# Predicted: jdjdujju, True: nbpgoecc
# Predicted: lussllsu, True: vtnyxbun
# Predicted: ggrrgrrr, True: hagsxtgu
# Predicted: txrbrtxr, True: ojzbltxk
# Predicted: qrqqqqrr, True: skjfvysc
# Predicted: mwemmrje, True: kqvngdzq
# Predicted: bttuuutt, True: lotyvivd
# Predicted: iiiziaai, True: xbkjutzg
# Predicted: aaaaaaaa, True: nwpwqmqt
# Predicted: tttttxvv, True: vkrruaeu
# Predicted: ppqpbbbp, True: fghmphbh
# Predicted: muwpfpef, True: jnbgaium
# Predicted: ozzzzozz, True: bnzzlxew
# Predicted: egitekkb, True: ydvuonhi
# Predicted: sksbkbbb, True: bkmgqegd
# Predicted: fnengfly, True: lebohjzl
# Predicted: zllssllz, True: purcrlzl
# Predicted: jggjlgsg, True: wvzlytey
# Predicted: vggvvvvv, True: pjoqwntb
# Predicted: ubembeme, True: hljxaoid
# Predicted: oototttt, True: lrsziieb
# Predicted: kiiiikii, True: mxdphjxa
# Predicted: ccjchmhc, True: sxtujmpj
# Predicted: ngnjgngn, True: dyhypwck
# Predicted: jlwuyjyy, True: bmywcjdy
# Predicted: byyyybbr, True: mcycxrqv
# Predicted: fqfggfff, True: wcxczgjc
# Predicted: ttgggttg, True: vijbfbuv
# Predicted: sslsskls, True: tqwjghrb
# Predicted: kikkkkki, True: glfmczmj
# Predicted: toootttt, True: ydfuiyal
# Predicted: qllqyqyy, True: tdbhwmqr
# Predicted: rnrvvvgv, True: yinfqrsv
# Predicted: ynyynnnn, True: qwisfmmd
# Predicted: cxcxxxxc, True: qaiigqoi
# Predicted: wwwywhhy, True: njnirdcp
# Predicted: zuzzzzuv, True: kjepcvvr
# Predicted: jgffzjjj, True: dfnsrqmh
# Predicted: yyyyyyyy, True: rhhortcl
# Predicted: quqssjqq, True: rmettpmn
# Predicted: qwgwtnrn, True: mziwycuv
# Predicted: ggktggtg, True: vzjnfbau
# Predicted: cccccwcw, True: nuguijml
# Predicted: avgggavn, True: lllqjdqx
# Predicted: sssrzrzs, True: myqrsxkb
# Predicted: xlxlxxxx, True: tglkvlec
# Predicted: kpyaanap, True: vckxjjli
# Predicted: ffgfffgg, True: dhtbqqto
# Predicted: sdsdddds, True: rwxrnwxy
# Predicted: dntgdehh, True: saaphwyi
# Predicted: iieeeeii, True: hdxdiwcv
# Predicted: xeexxeex, True: axumbqzf
# Predicted: kkkpkkkp, True: ersrizpp
# Predicted: imtiubdd, True: bcwydzxr
# Predicted: zrozyrrr, True: blxbfdzd
# Predicted: vcccudyc, True: pbtxijdu
# Predicted: fgfffgfg, True: jtioexxh
# Predicted: mggmvzmz, True: pwexcpnr
# Predicted: ggggttbg, True: ymirolrm
# Predicted: sgsookxs, True: jwzpices
# Predicted: fosrgofs, True: wxozlsoz
# Predicted: ljkllkkk, True: igrsztcd
# Predicted: fuuyuuyu, True: qejswyya
# Predicted: kaaaakka, True: jiugjjbx
# Predicted: htttthtt, True: nalvpffu
# Predicted: ttxtxttn, True: fvsfpcrl
# Predicted: sppsspsp, True: rdlytgxe
# Predicted: ssssssss, True: lksqmlyp
# Predicted: dvduuuuu, True: fayevojt
# Predicted: hvfmittm, True: kyncqdrj
# Predicted: javjaavj, True: pyhehyhj
# Predicted: ykkykkkp, True: fvvonzje
# Predicted: gggggbgp, True: yjfdqxcw
# Predicted: nntmnnqq, True: sdlwytdk
# Predicted: rqririrr, True: zzemcexf
# Predicted: cccccccc, True: qxtsupad
# Predicted: ymjwmwwm, True: rqumocaz
# Predicted: mtttxmtt, True: pirafbnr
# Predicted: jgjvjagx, True: cikkxitw
# Predicted: pgpkvgoo, True: vgbglxrd
# Predicted: ekebseyv, True: oilazbzs
# Predicted: rryryrry, True: oedpwqhy
# Predicted: ttqrqtot, True: xtsfoazs
# Predicted: iigdiggi, True: loqetwyg
# Predicted: dkyddydk, True: izulgoko
# Predicted: eeewenrr, True: hlwwxkda
# Predicted: bqvyaadr, True: iiqzjqkq
# Predicted: xxxxxxxx, True: bgmghyqs
# Predicted: dddddddd, True: fuhpgkes
# Predicted: alaaaaal, True: zhhmyyhl
# Predicted: iwviiviv, True: dkwbpjgj
# Predicted: wfiifiii, True: ecxfemba
# Predicted: cfinnfcf, True: pacfyaik
# Predicted: iwiwwwww, True: ujzhdgqn
# Predicted: xssxxfxs, True: txwhkqnu
# Predicted: ajarajaa, True: mieohaav
# Eval dataset results:
# Number of predictions with 0 correct predictions: 1464
# Number of predictions with 1 correct predictions: 472
# Number of predictions with 2 correct predictions: 60
# Number of predictions with 3 correct predictions: 4
# Number of predictions with 4 correct predictions: 0
# Number of predictions with 5 correct predictions: 0
# Number of predictions with 6 correct predictions: 0
# Number of predictions with 7 correct predictions: 0
# Number of predictions with 8 correct predictions: 0
# Points: 0.0
# Marks: 0.0
